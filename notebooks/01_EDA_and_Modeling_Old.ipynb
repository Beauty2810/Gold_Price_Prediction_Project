# %% [markdown]
# ## Project 148
# ## Gold Price Prediction

# %% [markdown]
# ### Business Objective:
#
# Data provided is related to gold prices. The objective is to understand the underlying structure in your dataset and come up with a suitable forecasting model which can effectively forecast gold prices for next 30 days.
# This forecast model will be used by gold exporting and gold importing companies to understand the metal price movements and accordingly set their revenue expectations.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.arima.model import sarimax
from statsmodels.tools.eval_measures import rmspe, rmse, aic
from sklearn.metrics import mean_absolute_percentage_error as mape
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the data

# %%
# read dataset
df = pd.read_csv("Gold_data.csv")
df.head()
# Out:
#          date    price
# 0  2016-01-01  2252.60
# 1  2016-01-02  2454.50
# 2  2016-01-03  2708.10
# 3  2016-01-04  2577.80
# 4  2016-01-05  2597.75

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2182 entries, 0 to 2181
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2182 non-null   object
#  1   price   2182 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 34.2+ KB

# %%
df.describe()
# Out:
#              price
# count  2182.000000
# mean   3284.450046
# std     719.564434
# min    2252.600000
# 25%    2697.020000
# 50%    2879.800000
# 75%    4147.325000
# max    4966.300000

# %%
# check if missing values
df.isnull().sum()
# Out:
# date     0
# price    0
# dtype: int64

# %%
# check if NA values
df.isna().sum()
# Out:
# date     0
# price    0
# dtype: int64

# %%
# convert date column in datetime format
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2182 entries, 0 to 2181
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2182 non-null   datetime64[ns]
#  1   price   2182 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 34.2 KB

# %%
df.head()
# Out:
#         date    price
# 0 2016-01-01  2252.60
# 1 2016-01-02  2454.50
# 2 2016-01-03  2708.10
# 3 2016-01-04  2577.80
# 4 2016-01-05  2597.75

# %%
df.tail()
# Out:
#            date   price
# 2177 2021-12-17  4394.4
# 2178 2021-12-18  4389.5
# 2179 2021-12-19  4389.5
# 2180 2021-12-20  4354.1
# 2181 2021-12-21  4346.5

# %%
# Set Index to Date Column
df.set_index('date', inplace=True)

# %%
# Plot Line Graph to check dataset
from matplotlib import dates 
from matplotlib.dates import MonthLocator, DateFormatter, YearLocator
### plot it
fig = plt.figure(figsize=[40, 20])
ax = fig.add_subplot(111)
ax.plot(df)
ax.xaxis.grid(True, which="minor")
ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n%b\n\n%Y'))
plt.tight_layout()

# %% [markdown]
# Observation: Trend and Seasonality in Time Series Data

# %%
# Monthly Plot Per Year Gold Price
import datetime
pt = pd.pivot_table(df, index=df.index.month, columns=df.index.year)
pt.columns = pt.columns.droplevel() # remove the double header (0) as pivot creates a multiindex.
ax = plt.figure(figsize=(10,6)).add_subplot(111)
ax.plot(pt)

ticklabels = [datetime.date(1900, item, 1).strftime('%b') for item in pt.index]
ax.set_xticks(np.arange(1,13))
ax.set_xticklabels(ticklabels) #add monthlabels to the xaxis

ax.legend(pt.columns.tolist(), loc='center left', bbox_to_anchor=(1, .5)) #add the column names as legend.
plt.tight_layout(rect=[1, 1, 1, 1])

plt.show()

# %%
import matplotlib.dates as mdates
# Quarterly Data
df_month = df.resample('MS').mean()
# plot it
fig = plt.figure(figsize=[15, 8])
ax = fig.add_subplot(111)
ax.plot(df_month)

months = mdates.MonthLocator((1,4,7,10))
ax.xaxis.grid(True, which="minor")
ax.yaxis.grid()
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(dates.DateFormatter('\n%b\n\n%Y'))
plt.tight_layout()

# %%
df_year = df.resample('YS').mean()
df_year
# Out:
#                   price
# date
# 2016-01-01  2690.614162
# 2017-01-01  2626.676484
# 2018-01-01  2781.938082
# 2019-01-01  3150.210685
# 2020-01-01  4216.378689
# 2021-01-01  4266.871549

# %%
# Annual Trend of Gold Price
fig = plt.figure(figsize=[15, 8])
ax = fig.add_subplot(111)
ax.plot(df_year)
ax.yaxis.grid()
plt.title('Annual Trend of Gold Price')
plt.ylabel('Gold Price')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# Yearly line plots
fig, ax = plt.subplots(3, 2, figsize=(15,10))
df.plot(xlim=['2021-01-01','2022-01-01'], ax=ax[0,0], c='red', title='2021-01-01 to 2022-01-01')
df.plot(xlim=['2020-01-01','2021-01-01'], ax=ax[0,1], c='blue', title='2020-01-01 to 2021-01-01')
df.plot(xlim=['2019-01-01','2020-01-01'], ax=ax[1,0], c='green', title='2019-01-01 to 2020-01-01')
df.plot(xlim=['2018-01-01','2019-01-01'], ax=ax[1,1], c='orange', title='2018-01-01 to 2019-01-01')
df.plot(xlim=['2017-01-01','2018-01-01'], ax=ax[2,0], c='purple', title='2017-01-01 to 2018-01-01')
df.plot(xlim=['2016-01-01','2017-01-01'], ax=ax[2,1], c='brown', title='2016-01-01 to 2017-01-01')
# Out:
# <AxesSubplot:title={'center':'2016-01-01 to 2017-01-01'}, xlabel='date'>

# %%
# Lag Plots
fig, ax = plt.subplots(2, 2, figsize=(15,10))
ax[0,0].set_title('One Lag Plot')
pd.plotting.lag_plot(df,ax=ax[0,0],c='red')
ax[0,1].set_title('Two Lag Plot')
pd.plotting.lag_plot(df,lag=2,ax=ax[0,1],c='green')
ax[1,0].set_title('Three Lag Plot')
pd.plotting.lag_plot(df,lag=3,ax=ax[1,0],c='blue')
ax[1,1].set_title('Four Lag Plot')
pd.plotting.lag_plot(df,lag=4,ax=ax[1,1],c='orange')
# Out:
# <AxesSubplot:title={'center':'Four Lag Plot'}, xlabel='y(t)', ylabel='y(t + 4)'>

# %%
# Time Series Histogram Plot
df.hist(figsize=(10,6))
plt.title('Gold Price Histogram Plot')
plt.xlabel('Gold Price')
plt.show()

# %%
# Time Series Density Plot
df.plot(kind='kde',figsize=(10,6))
plt.title('Gold Price Density Plot')
plt.xlabel('Gold Price')
plt.show()

# %%
# Box Plot to check outliers
import seaborn as sns
pt = pd.pivot_table(df, index=df.index.month, columns=df.index.year)
pt.columns = pt.columns.droplevel() # remove the double header (0) as pivot creates a multiindex.
pt.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# Yearly Box Plots
fig, ax = plt.subplots(3,2, figsize=(20,20))
for idx,year in enumerate(df.index.year.unique()):
    df.iloc[df.index.year==year].plot(kind='box',ax=ax[idx//2, idx%2], title=f'Boxplot for year {year}')
plt.subplots_adjust(wspace=0.4, hspace=0.4)
plt.show()

# %%
# decomposition of time series
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Additive Decompose
seasonal_decompose_add = seasonal_decompose(df['price'],period=365).plot()

# %% [markdown]
# Additive = (Trend + Seasonal + Residual (Noise))

# %%
# Multiplicative Decompose
seasonal_decompose_mul = seasonal_decompose(df['price'],period=365, model='multiplicative').plot()

# %% [markdown]
# Multiplcative = (Trend x Seasonal x Residual(Noise))

# %%
# Separating Cyclic and Trend component using hp_filter
from statsmodels.tsa.filters.hp_filter import hpfilter
df_cyclic, df_trend = hpfilter(df)

# %%
fig, ax = plt.subplots(1,2, figsize=(15,6))
df_cyclic.plot(ax=ax[0], title='Cyclic Component')
df_trend.plot(ax=ax[1], title='Trend Component')
ax[0].title.set_size(20); ax[1].title.set_size(20)

# %% [markdown]
# ## Detecting Time Series Stationarity

# %%
# checking time series data for stationary using Dickey Fuller Test, KPSS Test
from statsmodels.tsa.stattools import adfuller, kpss

# %%
# ADF Test
# Null Hypothesis - Data is not stationary
# Alternate Hypothesis - Data is stationary

# KPSS Test
# Null Hypothesis - Data is stationary
# Alternate Hypothesis - Data is not stationary

def check_stationarity(series):
    kps = kpss(series)
    adf = adfuller(series)
    kpss_pv, adf_pv = kps[1], adf[1]
    kpssh, adfh = 'Accept Null Hypothesis, Data is Stationary', 'Accept Null Hypothesis, Data is Non Stationary'
    if adf_pv < 0.05:
      adfh = 'Reject Null Hypothesis, Data is Stationary'
    if kpss_pv < 0.05:
      kpssh = 'Reject Null Hypothesis, Data is Non Stationary'
    return (f'KPSS: {kpssh}', f'ADF: {adfh}')

# %%
check_stationarity(df['price'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
def stationarity_results(df,t_name = [adfuller, kpss]):   
    result = []
    for stationary_test in t_name:
        output = stationary_test(df)
        test = stationary_test.__name__
        pval = output[1]
        test_score = output[0]
        lags = output[2]    
        decision = 'Non-Stationary'
        if test == 'adfuller':
            critical = output[4]
            if pval < 0.05:
                decision = 'Stationary'
        elif test=='kpss':
            critical = output[3]
            if pval >= 0.05: 
                decision = 'Stationary'            
        output_dict = {
        'Test Statistic': test_score,
        'p-value': pval,
        'Numbers of lags': lags,
        'decision': decision
        }
        for key, value in critical.items():
            output_dict["Critical Value (%s)" % key] = value
            
        result.append(pd.Series(output_dict, name=test))
    return pd.concat(result,axis=1)

# %%
stationarity_results(df['price'])
# Out:
#                              adfuller            kpss
# Test Statistic              -0.309904        6.729272
# p-value                       0.92409            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ## Making time series stationary

# %% [markdown]
# Other Techniques to make the TS Stationary
# 1. Differencing (One time, Two time) --> Stabilizes the mean
# 2. Seasonal Differencing
# 3. Log Transformation
# 4. Taking square root
# 5. Taking cube root
# 6. Box-cox (Hyperparameter= lambda) --> Stabilizes the variance
# 7. Subtracting moving average
# 8. Decomposition
# 9. hp_filter

# %% [markdown]
# ### One time differencing

# %%
# First Order Differencing - detrending
# df['one_diff'] = df['price']-df['price'].shift(1)
df['one_diff'] = df['price'].diff(1)
df['one_diff']
# Out:
# date
# 2016-01-01       NaN
# 2016-01-02    201.90
# 2016-01-03    253.60
# 2016-01-04   -130.30
# 2016-01-05     19.95
#                ...
# 2021-12-17     -5.40
# 2021-12-18     -4.90
# 2021-12-19      0.00
# 2021-12-20    -35.40
# 2021-12-21     -7.60
# Name: one_diff, Length: 2182, dtype: float64

# %%
df['one_diff'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# adfuller test on One difference
check_stationarity(df['one_diff'].dropna())
# Out:
# ('KPSS: Accept Null Hypothesis, Data is Stationary',
#  'ADF: Reject Null Hypothesis, Data is Stationary')

# %%
stationarity_results(df['one_diff'].dropna())
# Out:
#                          adfuller        kpss
# Test Statistic         -21.664542    0.017761
# p-value                       0.0         0.1
# Numbers of lags                26          22
# decision               Stationary  Stationary
# Critical Value (1%)      -3.43339       0.739
# Critical Value (5%)     -2.862883       0.463
# Critical Value (10%)    -2.567485       0.347
# Critical Value (2.5%)         NaN       0.574

# %% [markdown]
# ### Two time differencing

# %%
df['two_diff']=df['price'].diff(365).diff()

# %%
df['two_diff'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
check_stationarity(df['two_diff'].dropna())
# Out:
# ('KPSS: Accept Null Hypothesis, Data is Stationary',
#  'ADF: Reject Null Hypothesis, Data is Stationary')

# %%
stationarity_results(df['two_diff'].dropna())
# Out:
#                          adfuller        kpss
# Test Statistic         -16.757218    0.024209
# p-value                       0.0         0.1
# Numbers of lags                25          12
# decision               Stationary  Stationary
# Critical Value (1%)     -3.434008       0.739
# Critical Value (5%)     -2.863156       0.463
# Critical Value (10%)     -2.56763       0.347
# Critical Value (2.5%)         NaN       0.574

# %% [markdown]
# ### Log Transformation

# %%
df['log']=np.log(df['price'])

# %%
df['log'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Checking for Stationarity for Log transformed data
check_stationarity(df['log'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['log'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -0.457214        6.864523
# p-value                      0.900099            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ### Square root transformation

# %%
df['sqrt']=np.sqrt(df['price'])

# %%
df['sqrt'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Checking Stationarity for Square root transformed data
check_stationarity(df['sqrt'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['sqrt'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -0.372419        6.799565
# p-value                      0.914603            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ### Cube root tranformation

# %%
df['cube_root']=np.cbrt(df['price'])

# %%
df['cube_root'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Checking for Stationarity
check_stationarity(df['cube_root'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['cube_root'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -0.398242        6.821855
# p-value                      0.910392            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ### Log Square Root

# %%
df['log_sqrt'] = np.log(np.sqrt(df['price']))

# %%
df['log_sqrt'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Checking for Stationarity
check_stationarity(df['log_sqrt'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['log_sqrt'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -0.457214        6.864523
# p-value                      0.900099            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ### Subtracting Moving Average

# %%
# Subtract Moving Average
rolling=df['price'].rolling(365).mean()

# %%
df['subtract_MA']=df['price']-rolling

# %%
df['subtract_MA'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
check_stationarity(df['subtract_MA'].dropna())
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['subtract_MA'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -2.152317        1.590998
# p-value                      0.224004            0.01
# Numbers of lags                    25              25
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.434004           0.739
# Critical Value (5%)         -2.863154           0.463
# Critical Value (10%)        -2.567629           0.347
# Critical Value (2.5%)             NaN           0.574

# %%
seasonal_decompose_mul = seasonal_decompose(df['price'],period=365, model='multiplicative')

# %%
# df['seasonal_decomp']=seasonal_decompose_mul.seasonal*seasonal_decompose_mul.resid
df['seasonal_decomp']=seasonal_decompose_mul.observed - seasonal_decompose_mul.trend   # Actual values - Trend

# %%
df['seasonal_decomp'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
check_stationarity(df['seasonal_decomp'].dropna())
# Out:
# ('KPSS: Accept Null Hypothesis, Data is Stationary',
#  'ADF: Reject Null Hypothesis, Data is Stationary')

# %%
stationarity_results(df['subtract_MA'].dropna())
# Out:
#                              adfuller            kpss
# Test Statistic              -2.152317        1.590998
# p-value                      0.224004            0.01
# Numbers of lags                    25              25
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.434004           0.739
# Critical Value (5%)         -2.863154           0.463
# Critical Value (10%)        -2.567629           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ### hp_filter

# %%
df['cyclic'],_=hpfilter(df['price'])

# %%
df['cyclic'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
check_stationarity(df['cyclic'])
# Out:
# ('KPSS: Accept Null Hypothesis, Data is Stationary',
#  'ADF: Reject Null Hypothesis, Data is Stationary')

# %%
stationarity_results(df['cyclic'])
# Out:
#                          adfuller        kpss
# Test Statistic         -26.703287     0.00204
# p-value                       0.0         0.1
# Numbers of lags                26          12
# decision               Stationary  Stationary
# Critical Value (1%)     -3.433388       0.739
# Critical Value (5%)     -2.862882       0.463
# Critical Value (10%)    -2.567484       0.347
# Critical Value (2.5%)         NaN       0.574

# %% [markdown]
# ### Box-cox

# %% [markdown]
# - The Box-Cox transform is a configurable data transform method that supports both square root and log transform, as well as a suite of related transforms.
#
# - A Box-cox transformation is a power family transformation which transforms a non-normal dependent variable into Normal value.
#
# - The Box-Cox transform is given by::
#
#     y = (x**lmbda - 1) / lmbda,  for lmbda != 0
#         log(x),                  for lmbda = 0
#
# - Below are some common values for lambda
#
# 1. lambda = -1. is a reciprocal transform.
# 2. lambda = -0.5 is a reciprocal square root transform.
# 3. lambda = 0.0 is a log transform.
# 4. lambda = 0.5 is a square root transform.
# 5. lambda = 1.0 is no transform
#
# - Lambda can range from -5 to +5.

# %%
from scipy.stats import boxcox

# %%
# Apply all transformations and get lambda values for all
df['box_cox'],lmbda=boxcox(df['log_sqrt'])

# %%
# lambda value changes with type of transformation

# %%
lmbda
# Out:
# -17.25906645094103

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,6))
df['price'].hist(ax=ax[0])
df['box_cox'].hist(ax=ax[1])
plt.show()

# %%
is_normal(df['box_cox'])
# Out:
# Statistic: 1.0
# p_value 1.0
# shapiro test --> Normal
#  ==========================
#
# Statistic: 22011.82913679867
# p_value 0.0
# normaltest test --> Not Normal
#  ==========================
#
# Statistic: 102.57000197525986
# p_value 0.0
# normal_ad test --> Not Normal
#  ==========================
#
# Statistic: 0.1643129539581598
# p_value 0.0009999999999998899
# kstest_fit test --> Not Normal
#  ==========================

# %%
df['box_cox'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Checking Stationarity
check_stationarity(df['box_cox'])
# Out:
# ('KPSS: Reject Null Hypothesis, Data is Non Stationary',
#  'ADF: Accept Null Hypothesis, Data is Non Stationary')

# %%
stationarity_results(df['box_cox'])
# Out:
#                              adfuller            kpss
# Test Statistic              -1.065728        7.069206
# p-value                      0.728544            0.01
# Numbers of lags                    26              28
# decision               Non-Stationary  Non-Stationary
# Critical Value (1%)         -3.433388           0.739
# Critical Value (5%)         -2.862882           0.463
# Critical Value (10%)        -2.567484           0.347
# Critical Value (2.5%)             NaN           0.574

# %% [markdown]
# ## Split dataset

# %%
 def split_data(data, test_split):
    l = len(data)
    t_idx = round(l*(1-test_split))
    train, test = data[ : t_idx], data[t_idx : ]
    print(f'train: {len(train)} , test: {len(test)}')
    return train, test

# %%
test_split = 0.33
df_train, df_test = split_data(df, test_split)
# Out:
# train: 1462 , test: 720

# %%
df_train
# Out:
#               price  one_diff  two_diff       log       sqrt  cube_root  \
# date
# 2016-01-01  2252.60       NaN       NaN  7.719840  47.461563  13.108752
# 2016-01-02  2454.50    201.90       NaN  7.805678  49.542911  13.489246
# 2016-01-03  2708.10    253.60       NaN  7.904003  52.039408  13.938677
# 2016-01-04  2577.80   -130.30       NaN  7.854692  50.772040  13.711440
# 2016-01-05  2597.75     19.95       NaN  7.862401  50.968127  13.746721
# ...             ...       ...       ...       ...        ...        ...
# 2019-12-28  3464.20     -4.70      -2.2  8.150237  58.857455  15.131001
# 2019-12-29  3464.20      0.00       0.0  8.150237  58.857455  15.131001
# 2019-12-30  3469.40      5.20       5.2  8.151737  58.901613  15.138568
# 2019-12-31  3477.30      7.90      17.8  8.154011  58.968636  15.150050
# 2020-01-01  3477.60      0.30      -6.4  8.154098  58.971179  15.150485
#
#             log_sqrt  subtract_MA  seasonal_decomp      cyclic   box_cox
# date
# 2016-01-01  3.859920          NaN              NaN -360.016743  0.057941
# 2016-01-02  3.902839          NaN              NaN -154.997367  0.057941
# 2016-01-03  3.952001          NaN              NaN  101.947020  0.057941
# 2016-01-04  3.927346          NaN              NaN  -24.461699  0.057941
# 2016-01-05  3.931200          NaN              NaN    0.184643  0.057941
# ...              ...          ...              ...         ...       ...
# 2019-12-28  4.075119   318.958630      -187.040548 -149.324336  0.057941
# 2019-12-29  4.075119   317.327945      -190.265205 -182.967003  0.057941
# 2019-12-30  4.075868   320.883014      -188.282740 -212.239033  0.057941
# 2019-12-31  4.077006   327.089315      -184.305753 -239.209998  0.057941
# 2020-01-01  4.077049   325.713151      -185.718356 -273.616820  0.057941
#
# [1462 rows x 11 columns]

# %%
df_test
# Out:
#              price  one_diff  two_diff       log       sqrt  cube_root  \
# date
# 2020-01-02  3649.3     171.7      13.0  8.202291  60.409436  15.395833
# 2020-01-03  3672.8      23.5      99.5  8.208710  60.603630  15.428810
# 2020-01-04  3909.0     236.2     326.0  8.271037  62.521996  15.752708
# 2020-01-05  4145.9     236.9     242.2  8.329875  64.388664  16.064712
# 2020-01-06  4216.3      70.4       8.5  8.346713  64.933042  16.155132
# ...            ...       ...       ...       ...        ...        ...
# 2021-12-17  4394.4      -5.4     -47.1  8.388086  66.290271  16.379471
# 2021-12-18  4389.5      -4.9       5.2  8.386971  66.253302  16.373380
# 2021-12-19  4389.5       0.0      -5.3  8.386971  66.253302  16.373380
# 2021-12-20  4354.1     -35.4     -35.4  8.378873  65.985604  16.329246
# 2021-12-21  4346.5      -7.6     -18.7  8.377126  65.927991  16.319740
#
#             log_sqrt  subtract_MA  seasonal_decomp      cyclic   box_cox
# date
# 2020-01-02  4.101145   495.701370       -15.961918 -135.746913  0.057941
# 2020-01-03  4.104355   517.216986         4.506027 -144.316684  0.057941
# 2020-01-04  4.135518   750.539452       237.568219   62.542304  0.057941
# 2020-01-05  4.164938   983.898356       471.208493  273.888686  0.057941
# 2020-01-06  4.173357  1050.733973       538.833699  323.542008  0.057941
# ...              ...          ...              ...         ...       ...
# 2021-12-17  4.194043   122.069589              NaN   42.358372  0.057941
# 2021-12-18  4.193485   117.301918              NaN   31.054136  0.057941
# 2021-12-19  4.193485   117.448767              NaN   24.713520  0.057941
# 2021-12-20  4.189437    82.292603              NaN  -16.977921  0.057941
# 2021-12-21  4.188563    74.987671              NaN  -30.850082  0.057941
#
# [720 rows x 11 columns]

# %%
# Creating a function to compare the Scores and give the best model

def get_best_model(score, c='AIC'):
    initial_score = score[0][c]
    best_model = 0
    for k,v in score.items():
        if v[c] < initial_score:
            initial_score = v[c]
            best_model = k
    print(f'Best model: {best_model} with lowest {c} score: {initial_score}')
    return score[best_model]['model']

# %%
# Creating a function to plot the graphs

def plot_forecast(model, start, train, test):
    forecast = pd.DataFrame(model.forecast(test.shape[0]),index=test.index)
    ax = train.loc[start:].plot(style='--')
    test.plot(ax=ax)
    forecast.plot(ax=ax, style = '-.')
    ax.legend(['orig_train', 'orig_test', 'forecast'])
    plt.show()

# %%
# Creating a function for iterating between different values of parameters for hyperparameter tuning

from itertools import product
def combinator(items):
    combo = [i for i in product(*items)]
    return combo

# %% [markdown]
# ## ACF PACF plots

# %%
fig, ax = plt.subplots(2,1, figsize=(12,8))
plot_acf(df['one_diff'].dropna(), zero=False, ax=ax[0])
plot_pacf(df['one_diff'].dropna(), zero=False, ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(2,1, figsize=(12,8))
plot_acf(df['two_diff'].dropna(), zero=False, ax=ax[0])
plot_pacf(df['two_diff'].dropna(), zero=False, ax=ax[1])
plt.show()

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# ### Exponential Smoothing
# SimpleExpSmoothing: Simple exponential smoothing is used when the
# time series process lacks seasonality and trend. This is also referred to as single
# exponential smoothing
#
# Holt: Holt's exponential smoothing is an enhancement of the simple exponential
# smoothing and is used when the time series process contains only trend (but no
# seasonality). It is referred to as double exponential smoothing.
#
# ExponentialSmoothing: Holt-Winters' exponential smoothing is an
# enhancement of Holt's exponential smoothing and is used when the time
# series process has both seasonality and trend. It is referred to as triple
# exponential smoothing

# %% [markdown]
# ### Simple Exponential Smoothening

# %%
# Hyperparameter tuning
# Finding the best smoothing level for least MAPE score
x = np.linspace(0.1,1,50)
for i in x:
    ses_model = SimpleExpSmoothing(df_train['price']).fit(smoothing_level=i)
    s_pred = ses_model.predict(start=df_test.index[0],end=df_test.index[-1])
    mape_error = mape(s_pred, df_test['price'])
    #rmse_score = rmse(s_pred, df_test['price'])
    rmpse_score = rmspe(s_pred, df_test['price'])
    print('Smoothing Level--->', i ,'MAPE error',np.round( mape_error,2), 'RMPSE score', np.round(rmpse_score,3) )
# Out:
# Smoothing Level---> 0.1 MAPE error 0.24 RMPSE score 2.558
# Smoothing Level---> 0.11836734693877551 MAPE error 0.24 RMPSE score 2.515
# Smoothing Level---> 0.13673469387755102 MAPE error 0.24 RMPSE score 2.482
# Smoothing Level---> 0.15510204081632656 MAPE error 0.23 RMPSE score 2.456
# Smoothing Level---> 0.17346938775510207 MAPE error 0.23 RMPSE score 2.435
# Smoothing Level---> 0.19183673469387758 MAPE error 0.23 RMPSE score 2.419
# Smoothing Level---> 0.21020408163265308 MAPE error 0.23 RMPSE score 2.406
# Smoothing Level---> 0.2285714285714286 MAPE error 0.23 RMPSE score 2.395
# Smoothing Level---> 0.2469387755102041 MAPE error 0.23 RMPSE score 2.387
# Smoothing Level---> 0.2653061224489796 MAPE error 0.22 RMPSE score 2.379
# Smoothing Level---> 0.2836734693877551 MAPE error 0.22 RMPSE score 2.373
# Smoothing Level---> 0.3020408163265306 MAPE error 0.22 RMPSE score 2.368
# Smoothing Level---> 0.3204081632653062 MAPE error 0.22 RMPSE score 2.364
# Smoothing Level---> 0.3387755102040817 MAPE error 0.22 RMPSE score 2.36
# Smoothing Level---> 0.3571428571428572 MAPE error 0.22 RMPSE score 2.357
# Smoothing Level---> 0.3755102040816327 MAPE error 0.22 RMPSE score 2.354
# Smoothing Level---> 0.3938775510204082 MAPE error 0.22 RMPSE score 2.351
# Smoothing Level---> 0.41224489795918373 MAPE error 0.22 RMPSE score 2.349
# Smoothing Level---> 0.43061224489795924 MAPE error 0.22 RMPSE score 2.348
# Smoothing Level---> 0.44897959183673475 MAPE error 0.22 RMPSE score 2.346
# Smoothing Level---> 0.46734693877551026 MAPE error 0.22 RMPSE score 2.344
# Smoothing Level---> 0.48571428571428577 MAPE error 0.22 RMPSE score 2.343
# Smoothing Level---> 0.5040816326530613 MAPE error 0.22 RMPSE score 2.342
# Smoothing Level---> 0.5224489795918368 MAPE error 0.22 RMPSE score 2.341
# Smoothing Level---> 0.5408163265306123 MAPE error 0.22 RMPSE score 2.34
# Smoothing Level---> 0.5591836734693878 MAPE error 0.22 RMPSE score 2.339
# Smoothing Level---> 0.5775510204081633 MAPE error 0.22 RMPSE score 2.339
# Smoothing Level---> 0.5959183673469388 MAPE error 0.22 RMPSE score 2.338
# Smoothing Level---> 0.6142857142857143 MAPE error 0.22 RMPSE score 2.337
# Smoothing Level---> 0.6326530612244898 MAPE error 0.22 RMPSE score 2.337
# Smoothing Level---> 0.6510204081632653 MAPE error 0.22 RMPSE score 2.336
# Smoothing Level---> 0.6693877551020408 MAPE error 0.22 RMPSE score 2.336
# Smoothing Level---> 0.6877551020408164 MAPE error 0.22 RMPSE score 2.335
# Smoothing Level---> 0.7061224489795919 MAPE error 0.22 RMPSE score 2.335
# Smoothing Level---> 0.7244897959183674 MAPE error 0.22 RMPSE score 2.334
# Smoothing Level---> 0.7428571428571429 MAPE error 0.22 RMPSE score 2.334
# Smoothing Level---> 0.7612244897959184 MAPE error 0.22 RMPSE score 2.334
# Smoothing Level---> 0.7795918367346939 MAPE error 0.22 RMPSE score 2.333
# Smoothing Level---> 0.7979591836734694 MAPE error 0.22 RMPSE score 2.333
# Smoothing Level---> 0.8163265306122449 MAPE error 0.22 RMPSE score 2.333
# Smoothing Level---> 0.8346938775510204 MAPE error 0.22 RMPSE score 2.333
# Smoothing Level---> 0.8530612244897959 MAPE error 0.22 RMPSE score 2.333
# Smoothing Level---> 0.8714285714285714 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.889795918367347 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.9081632653061225 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.926530612244898 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.9448979591836735 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.963265306122449 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 0.9816326530612246 MAPE error 0.22 RMPSE score 2.332
# Smoothing Level---> 1.0 MAPE error 0.22 RMPSE score 2.332

# %%
ses_final_model = SimpleExpSmoothing(df_train['price']).fit(smoothing_level=0.2653)

# %%
# Plotting the Forecasted values
plot_forecast(ses_final_model,'2016',df_train['price'],df_test['price'])

# %% [markdown]
# ### Double Exponential Smoothening

# %%
# Finding best alphas and betas for the Double Exponential Smoothing:-
alphas = np.arange(0.1,1,0.09)
betas = np.arange(0.1,1,0.09)
l=[]
for i in alphas:
    for j in betas:
        des_model = Holt(df_train['price']).fit(smoothing_level=i,smoothing_slope=j)
        d_pred = des_model.predict(start=df_test.index[0],end=df_test.index[-1])
        mape_score= mape(d_pred,df_test['price'])
        rmspe_score=rmspe(d_pred,df_test['price'])
        print('Smoothing Level',i,'Smoothing Slope',j,'MAPE Error-->',np.round(mape_score,3), 'RMSPE',np.round(rmspe_score,3) )
        l.append((i,j,score))
# Out:
# Smoothing Level 0.1 Smoothing Slope 0.1 MAPE Error--> 0.403 RMSPE 4.456
# Smoothing Level 0.1 Smoothing Slope 0.19 MAPE Error--> 0.486 RMSPE 5.245
# Smoothing Level 0.1 Smoothing Slope 0.28 MAPE Error--> 0.372 RMSPE 4.131
# Smoothing Level 0.1 Smoothing Slope 0.37 MAPE Error--> 17.873 RMSPE 2566.695
# Smoothing Level 0.1 Smoothing Slope 0.45999999999999996 MAPE Error--> 5.29 RMSPE 415.715
# Smoothing Level 0.1 Smoothing Slope 0.5499999999999999 MAPE Error--> 12.11 RMSPE 1361.778
# Smoothing Level 0.1 Smoothing Slope 0.64 MAPE Error--> 0.348 RMSPE 3.945
# Smoothing Level 0.1 Smoothing Slope 0.73 MAPE Error--> 0.61 RMSPE 6.433
# Smoothing Level 0.1 Smoothing Slope 0.82 MAPE Error--> 0.692 RMSPE 7.186
# Smoothing Level 0.1 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.722 RMSPE 7.467
# Smoothing Level 0.19 Smoothing Slope 0.1 MAPE Error--> 0.366 RMSPE 4.087
# Smoothing Level 0.19 Smoothing Slope 0.19 MAPE Error--> 0.237 RMSPE 2.807
# Smoothing Level 0.19 Smoothing Slope 0.28 MAPE Error--> 0.123 RMSPE 1.444
# Smoothing Level 0.19 Smoothing Slope 0.37 MAPE Error--> 0.364 RMSPE 4.072
# Smoothing Level 0.19 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.508 RMSPE 5.461
# Smoothing Level 0.19 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.527 RMSPE 5.638
# Smoothing Level 0.19 Smoothing Slope 0.64 MAPE Error--> 0.426 RMSPE 4.665
# Smoothing Level 0.19 Smoothing Slope 0.73 MAPE Error--> 0.216 RMSPE 2.308
# Smoothing Level 0.19 Smoothing Slope 0.82 MAPE Error--> 6.915 RMSPE 375.5
# Smoothing Level 0.19 Smoothing Slope 0.9099999999999999 MAPE Error--> 7.608 RMSPE 1055.436
# Smoothing Level 0.28 Smoothing Slope 0.1 MAPE Error--> 0.327 RMSPE 3.706
# Smoothing Level 0.28 Smoothing Slope 0.19 MAPE Error--> 0.267 RMSPE 3.107
# Smoothing Level 0.28 Smoothing Slope 0.28 MAPE Error--> 0.313 RMSPE 3.572
# Smoothing Level 0.28 Smoothing Slope 0.37 MAPE Error--> 0.345 RMSPE 3.886
# Smoothing Level 0.28 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.228 RMSPE 2.712
# Smoothing Level 0.28 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.25 RMSPE 2.644
# Smoothing Level 0.28 Smoothing Slope 0.64 MAPE Error--> 1.939 RMSPE 27.56
# Smoothing Level 0.28 Smoothing Slope 0.73 MAPE Error--> 1.479 RMSPE 19.301
# Smoothing Level 0.28 Smoothing Slope 0.82 MAPE Error--> 0.349 RMSPE 3.711
# Smoothing Level 0.28 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.082 RMSPE 1.082
# Smoothing Level 0.37 Smoothing Slope 0.1 MAPE Error--> 0.311 RMSPE 3.552
# Smoothing Level 0.37 Smoothing Slope 0.19 MAPE Error--> 0.278 RMSPE 3.221
# Smoothing Level 0.37 Smoothing Slope 0.28 MAPE Error--> 0.267 RMSPE 3.109
# Smoothing Level 0.37 Smoothing Slope 0.37 MAPE Error--> 0.191 RMSPE 2.324
# Smoothing Level 0.37 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.087 RMSPE 1.054
# Smoothing Level 0.37 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.19 RMSPE 2.04
# Smoothing Level 0.37 Smoothing Slope 0.64 MAPE Error--> 0.225 RMSPE 2.387
# Smoothing Level 0.37 Smoothing Slope 0.73 MAPE Error--> 0.25 RMSPE 2.636
# Smoothing Level 0.37 Smoothing Slope 0.82 MAPE Error--> 0.382 RMSPE 4.089
# Smoothing Level 0.37 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.605 RMSPE 6.741
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.1 MAPE Error--> 0.301 RMSPE 3.453
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.19 MAPE Error--> 0.266 RMSPE 3.097
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.28 MAPE Error--> 0.22 RMSPE 2.633
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.37 MAPE Error--> 0.147 RMSPE 1.774
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.091 RMSPE 1.08
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.093 RMSPE 1.225
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.64 MAPE Error--> 0.139 RMSPE 1.576
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.73 MAPE Error--> 0.158 RMSPE 1.744
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.82 MAPE Error--> 0.119 RMSPE 1.417
# Smoothing Level 0.45999999999999996 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.087 RMSPE 1.065
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.1 MAPE Error--> 0.294 RMSPE 3.378
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.19 MAPE Error--> 0.254 RMSPE 2.981
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.28 MAPE Error--> 0.2 RMSPE 2.419
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.37 MAPE Error--> 0.143 RMSPE 1.713
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.104 RMSPE 1.206
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.088 RMSPE 1.067
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.64 MAPE Error--> 0.088 RMSPE 1.066
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.73 MAPE Error--> 0.1 RMSPE 1.168
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.82 MAPE Error--> 0.127 RMSPE 1.501
# Smoothing Level 0.5499999999999999 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.16 RMSPE 1.939
# Smoothing Level 0.64 Smoothing Slope 0.1 MAPE Error--> 0.288 RMSPE 3.323
# Smoothing Level 0.64 Smoothing Slope 0.19 MAPE Error--> 0.247 RMSPE 2.909
# Smoothing Level 0.64 Smoothing Slope 0.28 MAPE Error--> 0.194 RMSPE 2.35
# Smoothing Level 0.64 Smoothing Slope 0.37 MAPE Error--> 0.148 RMSPE 1.784
# Smoothing Level 0.64 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.12 RMSPE 1.417
# Smoothing Level 0.64 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.112 RMSPE 1.31
# Smoothing Level 0.64 Smoothing Slope 0.64 MAPE Error--> 0.119 RMSPE 1.395
# Smoothing Level 0.64 Smoothing Slope 0.73 MAPE Error--> 0.135 RMSPE 1.613
# Smoothing Level 0.64 Smoothing Slope 0.82 MAPE Error--> 0.155 RMSPE 1.88
# Smoothing Level 0.64 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.173 RMSPE 2.113
# Smoothing Level 0.73 Smoothing Slope 0.1 MAPE Error--> 0.284 RMSPE 3.283
# Smoothing Level 0.73 Smoothing Slope 0.19 MAPE Error--> 0.243 RMSPE 2.867
# Smoothing Level 0.73 Smoothing Slope 0.28 MAPE Error--> 0.192 RMSPE 2.336
# Smoothing Level 0.73 Smoothing Slope 0.37 MAPE Error--> 0.154 RMSPE 1.867
# Smoothing Level 0.73 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.133 RMSPE 1.588
# Smoothing Level 0.73 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.128 RMSPE 1.517
# Smoothing Level 0.73 Smoothing Slope 0.64 MAPE Error--> 0.132 RMSPE 1.583
# Smoothing Level 0.73 Smoothing Slope 0.73 MAPE Error--> 0.142 RMSPE 1.705
# Smoothing Level 0.73 Smoothing Slope 0.82 MAPE Error--> 0.15 RMSPE 1.815
# Smoothing Level 0.73 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.155 RMSPE 1.868
# Smoothing Level 0.82 Smoothing Slope 0.1 MAPE Error--> 0.281 RMSPE 3.251
# Smoothing Level 0.82 Smoothing Slope 0.19 MAPE Error--> 0.24 RMSPE 2.837
# Smoothing Level 0.82 Smoothing Slope 0.28 MAPE Error--> 0.192 RMSPE 2.329
# Smoothing Level 0.82 Smoothing Slope 0.37 MAPE Error--> 0.158 RMSPE 1.91
# Smoothing Level 0.82 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.138 RMSPE 1.658
# Smoothing Level 0.82 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.131 RMSPE 1.562
# Smoothing Level 0.82 Smoothing Slope 0.64 MAPE Error--> 0.13 RMSPE 1.548
# Smoothing Level 0.82 Smoothing Slope 0.73 MAPE Error--> 0.13 RMSPE 1.546
# Smoothing Level 0.82 Smoothing Slope 0.82 MAPE Error--> 0.127 RMSPE 1.505
# Smoothing Level 0.82 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.119 RMSPE 1.401
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.1 MAPE Error--> 0.278 RMSPE 3.223
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.19 MAPE Error--> 0.237 RMSPE 2.809
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.28 MAPE Error--> 0.19 RMSPE 2.308
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.37 MAPE Error--> 0.157 RMSPE 1.902
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.45999999999999996 MAPE Error--> 0.136 RMSPE 1.635
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.5499999999999999 MAPE Error--> 0.125 RMSPE 1.483
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.64 MAPE Error--> 0.118 RMSPE 1.38
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.73 MAPE Error--> 0.109 RMSPE 1.274
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.82 MAPE Error--> 0.098 RMSPE 1.149
# Smoothing Level 0.9099999999999999 Smoothing Slope 0.9099999999999999 MAPE Error--> 0.086 RMSPE 1.059

# %%
des_final_model = Holt(df_train['price']).fit(smoothing_trend=0.91,smoothing_level=0.91)

# %%
# Plotting the Forecasted values
plot_forecast(des_final_model,'2016',df_train['price'],df_test['price'])

# %% [markdown]
# ### Triple Exponential / Holt Winter's Smoothing

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %% [markdown]
# ### Trial 1

# %%
trend = ['add', 'mul']
damped = [True, False]
seasonal = ['add', 'mul']
use_boxcox = [True, False, 'log', -2.19]  
df_ex_comb = combinator([trend, damped, seasonal])
df_ex_comb
# Out:
# [('add', True, 'add'),
#  ('add', True, 'mul'),
#  ('add', False, 'add'),
#  ('add', False, 'mul'),
#  ('mul', True, 'add'),
#  ('mul', True, 'mul'),
#  ('mul', False, 'add'),
#  ('mul', False, 'mul')]

# %%
train = df_train['price'].dropna().values.ravel()
y = df_test['price'].dropna().values.ravel()
score = {}
for i, (t, dp,s) in enumerate(df_ex_comb):
    exp = ExponentialSmoothing(train, 
                     trend=t, 
                     damped_trend=dp,
                     seasonal=s,
                      seasonal_periods=365)
    model = exp.fit(use_brute=True, optimized=True)    
    y_hat = model.forecast(len(y))
    score[i] = {'trend':t, 
                'damped':dp,
                'AIC':model.aic,
                'BIC':model.bic, 
                'AICc':model.aicc, 
                'RMSPE': rmspe(y, y_hat),
                'RMSE' : rmse(y, y_hat),
                'MAPE' : mape(y, y_hat),
                'model': model}

# %%
df_best_model = get_best_model(score, 'AIC')
# Out:
# Best model: 3 with lowest AIC score: 12931.815629261573

# %%
df_best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                 1462
# Model:             ExponentialSmoothing   SSE                        6126068.859
# Optimized:                         True   AIC                          12931.816
# Trend:                         Additive   BIC                          14882.926
# Seasonal:                Multiplicative   AICC                         13185.049
# Seasonal Periods:                   365   Date:                 Thu, 06 Oct 2022
# Box-Cox:                          False   Time:                         08:05:49
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.9949997                alpha                 True
# smoothing_trend                0.0001003                 beta                 True
# smoothing_seasonal             0.0001000                gamma                 True
# initial_level                  2692.1914                  l.0                 True
# initial_trend                 -0.1155264                  b.0                 True
# initial_seasons.0              0.9772121                  s.0                 True
# initial_seasons.1              0.9961237                  s.1                 True
# initial_seasons.2              1.0541700                  s.2                 True
# initial_seasons.3              1.0410924                  s.3                 True
# initial_seasons.4              1.0372937                  s.4                 True
# initial_seasons.5              1.0422770                  s.5                 True
# initial_seasons.6              1.0762117                  s.6                 True
# initial_seasons.7              1.0865947                  s.7                 True
# initial_seasons.8              1.0862572                  s.8                 True
# initial_seasons.9              1.1293330                  s.9                 True
# initial_seasons.10             1.1157674                 s.10                 True
# initial_seasons.11             1.1074572                 s.11                 True
# initial_seasons.12             1.0669468                 s.12                 True
# initial_seasons.13             1.0093232                 s.13                 True
# initial_seasons.14             1.0148172                 s.14                 True
# initial_seasons.15             1.0162945                 s.15                 True
# initial_seasons.16             1.0177661                 s.16                 True
# initial_seasons.17             1.0188088                 s.17                 True
# initial_seasons.18             1.0159944                 s.18                 True
# initial_seasons.19             1.0147887                 s.19                 True
# initial_seasons.20             1.0152145                 s.20                 True
# initial_seasons.21             1.0147142                 s.21                 True
# initial_seasons.22             1.0169966                 s.22                 True
# initial_seasons.23             1.0163208                 s.23                 True
# initial_seasons.24             1.0190500                 s.24                 True
# initial_seasons.25             1.0195968                 s.25                 True
# initial_seasons.26             1.0209789                 s.26                 True
# initial_seasons.27             1.0191413                 s.27                 True
# initial_seasons.28             1.0188226                 s.28                 True
# initial_seasons.29             1.0227497                 s.29                 True
# initial_seasons.30             1.0239812                 s.30                 True
# initial_seasons.31             1.0271992                 s.31                 True
# initial_seasons.32             0.9962983                 s.32                 True
# initial_seasons.33             1.0499675                 s.33                 True
# initial_seasons.34             1.0486672                 s.34                 True
# initial_seasons.35             1.0384713                 s.35                 True
# initial_seasons.36             1.0248007                 s.36                 True
# initial_seasons.37             1.0487618                 s.37                 True
# initial_seasons.38             1.0777588                 s.38                 True
# initial_seasons.39             1.0701914                 s.39                 True
# initial_seasons.40             1.1114922                 s.40                 True
# initial_seasons.41             1.1092231                 s.41                 True
# initial_seasons.42             1.0910710                 s.42                 True
# initial_seasons.43             1.0710739                 s.43                 True
# initial_seasons.44             1.0278054                 s.44                 True
# initial_seasons.45             1.0348899                 s.45                 True
# initial_seasons.46             1.0394802                 s.46                 True
# initial_seasons.47             1.0460419                 s.47                 True
# initial_seasons.48             1.0452893                 s.48                 True
# initial_seasons.49             1.0507540                 s.49                 True
# initial_seasons.50             1.0511779                 s.50                 True
# initial_seasons.51             1.0485579                 s.51                 True
# initial_seasons.52             1.0417089                 s.52                 True
# initial_seasons.53             1.0440599                 s.53                 True
# initial_seasons.54             1.0504515                 s.54                 True
# initial_seasons.55             1.0486071                 s.55                 True
# initial_seasons.56             1.0472995                 s.56                 True
# initial_seasons.57             1.0487137                 s.57                 True
# initial_seasons.58             1.0478224                 s.58                 True
# initial_seasons.59             1.0440370                 s.59                 True
# initial_seasons.60             1.0022274                 s.60                 True
# initial_seasons.61             1.0138010                 s.61                 True
# initial_seasons.62             1.0300078                 s.62                 True
# initial_seasons.63             1.0220286                 s.63                 True
# initial_seasons.64             1.0260943                 s.64                 True
# initial_seasons.65             1.0248051                 s.65                 True
# initial_seasons.66             1.0510795                 s.66                 True
# initial_seasons.67             1.0661405                 s.67                 True
# initial_seasons.68             1.1091012                 s.68                 True
# initial_seasons.69             1.0997212                 s.69                 True
# initial_seasons.70             1.0976268                 s.70                 True
# initial_seasons.71             1.0800950                 s.71                 True
# initial_seasons.72             1.0183690                 s.72                 True
# initial_seasons.73             1.0098809                 s.73                 True
# initial_seasons.74             1.0058259                 s.74                 True
# initial_seasons.75             1.0102580                 s.75                 True
# initial_seasons.76             1.0180496                 s.76                 True
# initial_seasons.77             1.0116111                 s.77                 True
# initial_seasons.78             1.0145716                 s.78                 True
# initial_seasons.79             1.0136723                 s.79                 True
# initial_seasons.80             1.0169260                 s.80                 True
# initial_seasons.81             1.0250831                 s.81                 True
# initial_seasons.82             1.0219191                 s.82                 True
# initial_seasons.83             1.0238945                 s.83                 True
# initial_seasons.84             1.0255374                 s.84                 True
# initial_seasons.85             1.0253933                 s.85                 True
# initial_seasons.86             1.0231943                 s.86                 True
# initial_seasons.87             1.0197702                 s.87                 True
# initial_seasons.88             1.0176959                 s.88                 True
# initial_seasons.89             1.0185969                 s.89                 True
# initial_seasons.90             1.0141787                 s.90                 True
# initial_seasons.91             0.9744775                 s.91                 True
# initial_seasons.92             1.0156682                 s.92                 True
# initial_seasons.93             1.0327063                 s.93                 True
# initial_seasons.94             1.0181566                 s.94                 True
# initial_seasons.95             1.0224733                 s.95                 True
# initial_seasons.96             1.0384307                 s.96                 True
# initial_seasons.97             1.0636982                 s.97                 True
# initial_seasons.98             1.0670078                 s.98                 True
# initial_seasons.99             1.1171520                 s.99                 True
# initial_seasons.100            1.0926832                s.100                 True
# initial_seasons.101            1.1009926                s.101                 True
# initial_seasons.102            1.0814670                s.102                 True
# initial_seasons.103            1.0219606                s.103                 True
# initial_seasons.104            1.0212136                s.104                 True
# initial_seasons.105            1.0217829                s.105                 True
# initial_seasons.106            1.0207722                s.106                 True
# initial_seasons.107            1.0199063                s.107                 True
# initial_seasons.108            1.0224829                s.108                 True
# initial_seasons.109            1.0274167                s.109                 True
# initial_seasons.110            1.0246154                s.110                 True
# initial_seasons.111            1.0234409                s.111                 True
# initial_seasons.112            1.0233947                s.112                 True
# initial_seasons.113            1.0217919                s.113                 True
# initial_seasons.114            1.0232786                s.114                 True
# initial_seasons.115            1.0244093                s.115                 True
# initial_seasons.116            1.0234672                s.116                 True
# initial_seasons.117            1.0231941                s.117                 True
# initial_seasons.118            1.0261733                s.118                 True
# initial_seasons.119            1.0282811                s.119                 True
# initial_seasons.120            1.0057063                s.120                 True
# initial_seasons.121            0.9726565                s.121                 True
# initial_seasons.122            1.0117768                s.122                 True
# initial_seasons.123            1.0088483                s.123                 True
# initial_seasons.124            1.0115148                s.124                 True
# initial_seasons.125            1.0194637                s.125                 True
# initial_seasons.126            1.0468497                s.126                 True
# initial_seasons.127            1.0556153                s.127                 True
# initial_seasons.128            1.0772543                s.128                 True
# initial_seasons.129            1.1065798                s.129                 True
# initial_seasons.130            1.0894583                s.130                 True
# initial_seasons.131            1.0762472                s.131                 True
# initial_seasons.132            1.0602559                s.132                 True
# initial_seasons.133            1.0287631                s.133                 True
# initial_seasons.134            1.0271207                s.134                 True
# initial_seasons.135            1.0233945                s.135                 True
# initial_seasons.136            1.0205687                s.136                 True
# initial_seasons.137            1.0221880                s.137                 True
# initial_seasons.138            1.0251089                s.138                 True
# initial_seasons.139            1.0204477                s.139                 True
# initial_seasons.140            1.0217807                s.140                 True
# initial_seasons.141            1.0199083                s.141                 True
# initial_seasons.142            1.0192493                s.142                 True
# initial_seasons.143            1.0238207                s.143                 True
# initial_seasons.144            1.0218330                s.144                 True
# initial_seasons.145            1.0164956                s.145                 True
# initial_seasons.146            1.0173407                s.146                 True
# initial_seasons.147            1.0155545                s.147                 True
# initial_seasons.148            1.0132860                s.148                 True
# initial_seasons.149            1.0166522                s.149                 True
# initial_seasons.150            1.0170753                s.150                 True
# initial_seasons.151            1.0195846                s.151                 True
# initial_seasons.152            0.9822853                s.152                 True
# initial_seasons.153            1.0074457                s.153                 True
# initial_seasons.154            1.0050091                s.154                 True
# initial_seasons.155            1.0074581                s.155                 True
# initial_seasons.156            1.0266931                s.156                 True
# initial_seasons.157            1.0298704                s.157                 True
# initial_seasons.158            1.0538795                s.158                 True
# initial_seasons.159            1.0762581                s.159                 True
# initial_seasons.160            1.1005957                s.160                 True
# initial_seasons.161            1.0796314                s.161                 True
# initial_seasons.162            1.0719622                s.162                 True
# initial_seasons.163            1.0525090                s.163                 True
# initial_seasons.164            1.0317764                s.164                 True
# initial_seasons.165            1.0387999                s.165                 True
# initial_seasons.166            1.0336532                s.166                 True
# initial_seasons.167            1.0375282                s.167                 True
# initial_seasons.168            1.0335033                s.168                 True
# initial_seasons.169            1.0316670                s.169                 True
# initial_seasons.170            1.0322216                s.170                 True
# initial_seasons.171            1.0370524                s.171                 True
# initial_seasons.172            1.0386876                s.172                 True
# initial_seasons.173            1.0399867                s.173                 True
# initial_seasons.174            1.0390125                s.174                 True
# initial_seasons.175            1.0513269                s.175                 True
# initial_seasons.176            1.0538373                s.176                 True
# initial_seasons.177            1.0506244                s.177                 True
# initial_seasons.178            1.0531946                s.178                 True
# initial_seasons.179            1.0495085                s.179                 True
# initial_seasons.180            1.0511718                s.180                 True
# initial_seasons.181            1.0494607                s.181                 True
# initial_seasons.182            0.9830737                s.182                 True
# initial_seasons.183            1.0119432                s.183                 True
# initial_seasons.184            1.0158990                s.184                 True
# initial_seasons.185            1.0108414                s.185                 True
# initial_seasons.186            1.0171329                s.186                 True
# initial_seasons.187            1.0289932                s.187                 True
# initial_seasons.188            1.0456432                s.188                 True
# initial_seasons.189            1.0719607                s.189                 True
# initial_seasons.190            1.0980675                s.190                 True
# initial_seasons.191            1.0785489                s.191                 True
# initial_seasons.192            1.0733686                s.192                 True
# initial_seasons.193            1.0507478                s.193                 True
# initial_seasons.194            1.0349689                s.194                 True
# initial_seasons.195            1.0320406                s.195                 True
# initial_seasons.196            1.0318716                s.196                 True
# initial_seasons.197            1.0309900                s.197                 True
# initial_seasons.198            1.0343388                s.198                 True
# initial_seasons.199            1.0405615                s.199                 True
# initial_seasons.200            1.0368537                s.200                 True
# initial_seasons.201            1.0348162                s.201                 True
# initial_seasons.202            1.0373343                s.202                 True
# initial_seasons.203            1.0374216                s.203                 True
# initial_seasons.204            1.0353472                s.204                 True
# initial_seasons.205            1.0359799                s.205                 True
# initial_seasons.206            1.0341914                s.206                 True
# initial_seasons.207            1.0338752                s.207                 True
# initial_seasons.208            1.0364027                s.208                 True
# initial_seasons.209            1.0387693                s.209                 True
# initial_seasons.210            1.0400549                s.210                 True
# initial_seasons.211            1.0255732                s.211                 True
# initial_seasons.212            1.0078700                s.212                 True
# initial_seasons.213            0.9698816                s.213                 True
# initial_seasons.214            1.0064783                s.214                 True
# initial_seasons.215            1.0054607                s.215                 True
# initial_seasons.216            0.9980378                s.216                 True
# initial_seasons.217            0.9988215                s.217                 True
# initial_seasons.218            1.0175506                s.218                 True
# initial_seasons.219            1.0388743                s.219                 True
# initial_seasons.220            1.0535923                s.220                 True
# initial_seasons.221            1.0857671                s.221                 True
# initial_seasons.222            1.0777830                s.222                 True
# initial_seasons.223            1.0612256                s.223                 True
# initial_seasons.224            1.0368199                s.224                 True
# initial_seasons.225            1.0403465                s.225                 True
# initial_seasons.226            1.0580243                s.226                 True
# initial_seasons.227            1.0661023                s.227                 True
# initial_seasons.228            1.0628864                s.228                 True
# initial_seasons.229            1.0650565                s.229                 True
# initial_seasons.230            1.0690237                s.230                 True
# initial_seasons.231            1.0670370                s.231                 True
# initial_seasons.232            1.0696388                s.232                 True
# initial_seasons.233            1.0687031                s.233                 True
# initial_seasons.234            1.0699627                s.234                 True
# initial_seasons.235            1.0767326                s.235                 True
# initial_seasons.236            1.0760630                s.236                 True
# initial_seasons.237            1.0743426                s.237                 True
# initial_seasons.238            1.0744649                s.238                 True
# initial_seasons.239            1.0786489                s.239                 True
# initial_seasons.240            1.0786977                s.240                 True
# initial_seasons.241            1.0843708                s.241                 True
# initial_seasons.242            1.0825875                s.242                 True
# initial_seasons.243            1.0807598                s.243                 True
# initial_seasons.244            0.9942765                s.244                 True
# initial_seasons.245            1.0013493                s.245                 True
# initial_seasons.246            0.9988615                s.246                 True
# initial_seasons.247            0.9973061                s.247                 True
# initial_seasons.248            1.0003871                s.248                 True
# initial_seasons.249            1.0142867                s.249                 True
# initial_seasons.250            1.0252526                s.250                 True
# initial_seasons.251            1.0571483                s.251                 True
# initial_seasons.252            1.0706431                s.252                 True
# initial_seasons.253            1.0732569                s.253                 True
# initial_seasons.254            1.0568478                s.254                 True
# initial_seasons.255            1.0424734                s.255                 True
# initial_seasons.256            1.0685414                s.256                 True
# initial_seasons.257            1.0682873                s.257                 True
# initial_seasons.258            1.0645451                s.258                 True
# initial_seasons.259            1.0698726                s.259                 True
# initial_seasons.260            1.0717539                s.260                 True
# initial_seasons.261            1.0689486                s.261                 True
# initial_seasons.262            1.0707812                s.262                 True
# initial_seasons.263            1.0740780                s.263                 True
# initial_seasons.264            1.0751689                s.264                 True
# initial_seasons.265            1.0779854                s.265                 True
# initial_seasons.266            1.0766059                s.266                 True
# initial_seasons.267            1.0825871                s.267                 True
# initial_seasons.268            1.0765975                s.268                 True
# initial_seasons.269            1.0763742                s.269                 True
# initial_seasons.270            1.0661091                s.270                 True
# initial_seasons.271            1.0649611                s.271                 True
# initial_seasons.272            1.0651415                s.272                 True
# initial_seasons.273            1.0583936                s.273                 True
# initial_seasons.274            0.9933449                s.274                 True
# initial_seasons.275            0.9958255                s.275                 True
# initial_seasons.276            0.9959828                s.276                 True
# initial_seasons.277            0.9977811                s.277                 True
# initial_seasons.278            0.9947462                s.278                 True
# initial_seasons.279            1.0003780                s.279                 True
# initial_seasons.280            1.0161045                s.280                 True
# initial_seasons.281            1.0570456                s.281                 True
# initial_seasons.282            1.0602439                s.282                 True
# initial_seasons.283            1.0561248                s.283                 True
# initial_seasons.284            1.0490638                s.284                 True
# initial_seasons.285            1.0540121                s.285                 True
# initial_seasons.286            1.0576537                s.286                 True
# initial_seasons.287            1.0576572                s.287                 True
# initial_seasons.288            1.0591237                s.288                 True
# initial_seasons.289            1.0589777                s.289                 True
# initial_seasons.290            1.0575818                s.290                 True
# initial_seasons.291            1.0578005                s.291                 True
# initial_seasons.292            1.0595623                s.292                 True
# initial_seasons.293            1.0601575                s.293                 True
# initial_seasons.294            1.0570295                s.294                 True
# initial_seasons.295            1.0574278                s.295                 True
# initial_seasons.296            1.0575191                s.296                 True
# initial_seasons.297            1.0630368                s.297                 True
# initial_seasons.298            1.0618664                s.298                 True
# initial_seasons.299            1.0623548                s.299                 True
# initial_seasons.300            1.0609073                s.300                 True
# initial_seasons.301            1.0592012                s.301                 True
# initial_seasons.302            1.0605025                s.302                 True
# initial_seasons.303            1.0614031                s.303                 True
# initial_seasons.304            1.0659806                s.304                 True
# initial_seasons.305            0.9570329                s.305                 True
# initial_seasons.306            0.9975558                s.306                 True
# initial_seasons.307            0.9945753                s.307                 True
# initial_seasons.308            0.9918253                s.308                 True
# initial_seasons.309            0.9948069                s.309                 True
# initial_seasons.310            1.0057780                s.310                 True
# initial_seasons.311            1.0202929                s.311                 True
# initial_seasons.312            1.0559443                s.312                 True
# initial_seasons.313            1.0645998                s.313                 True
# initial_seasons.314            1.0559444                s.314                 True
# initial_seasons.315            1.0399851                s.315                 True
# initial_seasons.316            1.0399274                s.316                 True
# initial_seasons.317            1.0430111                s.317                 True
# initial_seasons.318            1.0437416                s.318                 True
# initial_seasons.319            1.0434132                s.319                 True
# initial_seasons.320            1.0463618                s.320                 True
# initial_seasons.321            1.0454018                s.321                 True
# initial_seasons.322            1.0459235                s.322                 True
# initial_seasons.323            1.0458535                s.323                 True
# initial_seasons.324            1.0455679                s.324                 True
# initial_seasons.325            1.0427874                s.325                 True
# initial_seasons.326            1.0433664                s.326                 True
# initial_seasons.327            1.0375272                s.327                 True
# initial_seasons.328            1.0375737                s.328                 True
# initial_seasons.329            1.0357115                s.329                 True
# initial_seasons.330            1.0370816                s.330                 True
# initial_seasons.331            1.0334170                s.331                 True
# initial_seasons.332            1.0346663                s.332                 True
# initial_seasons.333            1.0352469                s.333                 True
# initial_seasons.334            1.0332059                s.334                 True
# initial_seasons.335            0.9577336                s.335                 True
# initial_seasons.336            0.9968076                s.336                 True
# initial_seasons.337            0.9909036                s.337                 True
# initial_seasons.338            0.9897296                s.338                 True
# initial_seasons.339            0.9904993                s.339                 True
# initial_seasons.340            1.0083787                s.340                 True
# initial_seasons.341            1.0130271                s.341                 True
# initial_seasons.342            1.0506789                s.342                 True
# initial_seasons.343            1.0550316                s.343                 True
# initial_seasons.344            1.0431974                s.344                 True
# initial_seasons.345            1.0186268                s.345                 True
# initial_seasons.346            1.0050210                s.346                 True
# initial_seasons.347            1.0035340                s.347                 True
# initial_seasons.348            1.0028384                s.348                 True
# initial_seasons.349            0.9955136                s.349                 True
# initial_seasons.350            0.9953702                s.350                 True
# initial_seasons.351            0.9943334                s.351                 True
# initial_seasons.352            0.9882313                s.352                 True
# initial_seasons.353            0.9868224                s.353                 True
# initial_seasons.354            0.9844911                s.354                 True
# initial_seasons.355            0.9820642                s.355                 True
# initial_seasons.356            0.9793714                s.356                 True
# initial_seasons.357            0.9788709                s.357                 True
# initial_seasons.358            0.9817076                s.358                 True
# initial_seasons.359            0.9792313                s.359                 True
# initial_seasons.360            0.9787976                s.360                 True
# initial_seasons.361            0.9827678                s.361                 True
# initial_seasons.362            0.9822224                s.362                 True
# initial_seasons.363            0.9797664                s.363                 True
# initial_seasons.364            0.9775350                s.364                 True
# ----------------------------------------------------------------------------------
# """

# %%
plot_forecast(df_best_model, '2016', df_train['price'], df_test['price'])

# %%
score[3]
# Out:
# {'trend': 'add',
#  'damped': False,
#  'AIC': 12931.815629261573,
#  'BIC': 14882.92550553586,
#  'AICc': 13185.04865678451,
#  'RMSPE': 1.5484027784850116,
#  'RMSE': 677.0881324317493,
#  'MAPE': 0.14485250706925448,
#  'model': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x1cf75930f10>}

# %%
future = df_best_model.forecast(30)

# %%
pd.Series(future).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Trial 2

# %%
trend = ['add', 'mul']
damped = [True, False]
seasonal = ['add', 'mul']
use_boxcox = [True, False, 'log', -2.19]
initialization_method = ['estimated','heuristic','legacy-heuristic']
df_ex_comb = combinator([trend, damped, seasonal, use_boxcox,initialization_method])
df_ex_comb
# Out:
# [('add', True, 'add', True, 'estimated'),
#  ('add', True, 'add', True, 'heuristic'),
#  ('add', True, 'add', True, 'legacy-heuristic'),
#  ('add', True, 'add', False, 'estimated'),
#  ('add', True, 'add', False, 'heuristic'),
#  ('add', True, 'add', False, 'legacy-heuristic'),
#  ('add', True, 'add', 'log', 'estimated'),
#  ('add', True, 'add', 'log', 'heuristic'),
#  ('add', True, 'add', 'log', 'legacy-heuristic'),
#  ('add', True, 'add', -2.19, 'estimated'),
#  ('add', True, 'add', -2.19, 'heuristic'),
#  ('add', True, 'add', -2.19, 'legacy-heuristic'),
#  ('add', True, 'mul', True, 'estimated'),
#  ('add', True, 'mul', True, 'heuristic'),
#  ('add', True, 'mul', True, 'legacy-heuristic'),
#  ('add', True, 'mul', False, 'estimated'),
#  ('add', True, 'mul', False, 'heuristic'),
#  ('add', True, 'mul', False, 'legacy-heuristic'),
#  ('add', True, 'mul', 'log', 'estimated'),
#  ('add', True, 'mul', 'log', 'heuristic'),
#  ('add', True, 'mul', 'log', 'legacy-heuristic'),
#  ('add', True, 'mul', -2.19, 'estimated'),
#  ('add', True, 'mul', -2.19, 'heuristic'),
#  ('add', True, 'mul', -2.19, 'legacy-heuristic'),
#  ('add', False, 'add', True, 'estimated'),
#  ('add', False, 'add', True, 'heuristic'),
#  ('add', False, 'add', True, 'legacy-heuristic'),
#  ('add', False, 'add', False, 'estimated'),
#  ('add', False, 'add', False, 'heuristic'),
#  ('add', False, 'add', False, 'legacy-heuristic'),
#  ('add', False, 'add', 'log', 'estimated'),
#  ('add', False, 'add', 'log', 'heuristic'),
#  ('add', False, 'add', 'log', 'legacy-heuristic'),
#  ('add', False, 'add', -2.19, 'estimated'),
#  ('add', False, 'add', -2.19, 'heuristic'),
#  ('add', False, 'add', -2.19, 'legacy-heuristic'),
#  ('add', False, 'mul', True, 'estimated'),
#  ('add', False, 'mul', True, 'heuristic'),
#  ('add', False, 'mul', True, 'legacy-heuristic'),
#  ('add', False, 'mul', False, 'estimated'),
#  ('add', False, 'mul', False, 'heuristic'),
#  ('add', False, 'mul', False, 'legacy-heuristic'),
#  ('add', False, 'mul', 'log', 'estimated'),
#  ('add', False, 'mul', 'log', 'heuristic'),
#  ('add', False, 'mul', 'log', 'legacy-heuristic'),
#  ('add', False, 'mul', -2.19, 'estimated'),
#  ('add', False, 'mul', -2.19, 'heuristic'),
#  ('add', False, 'mul', -2.19, 'legacy-heuristic'),
#  ('mul', True, 'add', True, 'estimated'),
#  ('mul', True, 'add', True, 'heuristic'),
#  ('mul', True, 'add', True, 'legacy-heuristic'),
#  ('mul', True, 'add', False, 'estimated'),
#  ('mul', True, 'add', False, 'heuristic'),
#  ('mul', True, 'add', False, 'legacy-heuristic'),
#  ('mul', True, 'add', 'log', 'estimated'),
#  ('mul', True, 'add', 'log', 'heuristic'),
#  ('mul', True, 'add', 'log', 'legacy-heuristic'),
#  ('mul', True, 'add', -2.19, 'estimated'),
#  ('mul', True, 'add', -2.19, 'heuristic'),
#  ('mul', True, 'add', -2.19, 'legacy-heuristic'),
#  ('mul', True, 'mul', True, 'estimated'),
#  ('mul', True, 'mul', True, 'heuristic'),
#  ('mul', True, 'mul', True, 'legacy-heuristic'),
#  ('mul', True, 'mul', False, 'estimated'),
#  ('mul', True, 'mul', False, 'heuristic'),
#  ('mul', True, 'mul', False, 'legacy-heuristic'),
#  ('mul', True, 'mul', 'log', 'estimated'),
#  ('mul', True, 'mul', 'log', 'heuristic'),
#  ('mul', True, 'mul', 'log', 'legacy-heuristic'),
#  ('mul', True, 'mul', -2.19, 'estimated'),
#  ('mul', True, 'mul', -2.19, 'heuristic'),
#  ('mul', True, 'mul', -2.19, 'legacy-heuristic'),
#  ('mul', False, 'add', True, 'estimated'),
#  ('mul', False, 'add', True, 'heuristic'),
#  ('mul', False, 'add', True, 'legacy-heuristic'),
#  ('mul', False, 'add', False, 'estimated'),
#  ('mul', False, 'add', False, 'heuristic'),
#  ('mul', False, 'add', False, 'legacy-heuristic'),
#  ('mul', False, 'add', 'log', 'estimated'),
#  ('mul', False, 'add', 'log', 'heuristic'),
#  ('mul', False, 'add', 'log', 'legacy-heuristic'),
#  ('mul', False, 'add', -2.19, 'estimated'),
#  ('mul', False, 'add', -2.19, 'heuristic'),
#  ('mul', False, 'add', -2.19, 'legacy-heuristic'),
#  ('mul', False, 'mul', True, 'estimated'),
#  ('mul', False, 'mul', True, 'heuristic'),
#  ('mul', False, 'mul', True, 'legacy-heuristic'),
#  ('mul', False, 'mul', False, 'estimated'),
#  ('mul', False, 'mul', False, 'heuristic'),
#  ('mul', False, 'mul', False, 'legacy-heuristic'),
#  ('mul', False, 'mul', 'log', 'estimated'),
#  ('mul', False, 'mul', 'log', 'heuristic'),
#  ('mul', False, 'mul', 'log', 'legacy-heuristic'),
#  ('mul', False, 'mul', -2.19, 'estimated'),
#  ('mul', False, 'mul', -2.19, 'heuristic'),
#  ('mul', False, 'mul', -2.19, 'legacy-heuristic')]

# %%
train = df_train['one_diff'].dropna().values.ravel()
y = df_test['one_diff'].dropna().values.ravel()
ExponentialSmoothing(train)

# %%
import numpy
train = df_train['price'].dropna().values.ravel()
y = df_test['price'].dropna().values.ravel()
score = {}
for i, (t, dp,s,b,im) in enumerate(df_ex_comb):
    exp = ExponentialSmoothing(train, 
                     trend=t, 
                     damped_trend=dp,
                     seasonal=s,
                      seasonal_periods=365,
                      use_boxcox=True,
                      initialization_method=im)
    model = exp.fit(use_brute=True, optimized=True)    
    y_hat = model.forecast(len(y))
    score[i] = {'trend':t, 
                'damped':dp,
                'AIC':model.aic,
                'BIC':model.bic, 
                'AICc':model.aicc,
#                 'RMSPE': rmspe(y, y_hat),
#                 'RMSE' : rmse(y, y_hat),
#                 'MAPE' : mape(y, y_hat),
                'model': model}

# %%
df_best_model.params
# Out:
# {'smoothing_level': 0.9949997103841695,
#  'smoothing_trend': 0.00010029305049741788,
#  'smoothing_seasonal': 0.00010000720930386603,
#  'damping_trend': nan,
#  'initial_level': 2692.1913926291113,
#  'initial_trend': -0.11552641099223844,
#  'initial_seasons': array([0.97721208, 0.99612366, 1.05416996, 1.04109237, 1.03729367,
#         1.04227702, 1.0762117 , 1.08659468, 1.08625717, 1.12933295,
#         1.11576737, 1.10745721, 1.06694684, 1.00932315, 1.01481716,
#         1.01629449, 1.01776613, 1.01880882, 1.01599437, 1.01478868,
#         1.01521448, 1.01471418, 1.01699659, 1.01632085, 1.01905004,
#         1.01959675, 1.02097887, 1.01914126, 1.01882262, 1.02274967,
#         1.02398117, 1.02719917, 0.99629835, 1.04996754, 1.04866716,
#         1.03847131, 1.02480073, 1.0487618 , 1.07775882, 1.07019143,
#         1.11149217, 1.10922313, 1.09107102, 1.07107393, 1.02780538,
#         1.03488991, 1.03948017, 1.04604186, 1.04528926, 1.05075396,
#         1.05117791, 1.04855788, 1.04170891, 1.04405987, 1.0504515 ,
#         1.04860714, 1.04729947, 1.04871374, 1.04782242, 1.044037  ,
#         1.00222738, 1.01380104, 1.03000783, 1.02202864, 1.02609428,
#         1.02480512, 1.05107947, 1.06614051, 1.10910123, 1.09972117,
#         1.09762684, 1.08009505, 1.01836904, 1.00988092, 1.00582594,
#         1.01025797, 1.01804956, 1.01161113, 1.01457164, 1.01367226,
#         1.01692603, 1.02508314, 1.0219191 , 1.02389445, 1.0255374 ,
#         1.02539326, 1.0231943 , 1.01977015, 1.01769587, 1.01859695,
#         1.01417865, 0.97447752, 1.01566817, 1.03270634, 1.01815658,
#         1.02247329, 1.03843072, 1.06369822, 1.06700784, 1.11715204,
#         1.09268325, 1.10099258, 1.08146705, 1.02196064, 1.02121362,
#         1.02178289, 1.02077225, 1.01990634, 1.02248288, 1.02741673,
#         1.02461535, 1.02344093, 1.02339467, 1.02179189, 1.02327858,
#         1.02440929, 1.02346724, 1.02319412, 1.02617329, 1.02828105,
#         1.00570628, 0.97265654, 1.01177683, 1.00884828, 1.01151482,
#         1.01946369, 1.04684969, 1.05561527, 1.07725425, 1.1065798 ,
#         1.08945831, 1.07624722, 1.06025589, 1.02876314, 1.02712074,
#         1.02339451, 1.0205687 , 1.02218799, 1.02510888, 1.02044766,
#         1.02178072, 1.01990827, 1.01924934, 1.02382075, 1.02183296,
#         1.01649558, 1.01734068, 1.01555449, 1.01328601, 1.01665223,
#         1.01707531, 1.01958464, 0.98228529, 1.00744575, 1.00500908,
#         1.00745807, 1.02669306, 1.02987042, 1.05387948, 1.07625814,
#         1.10059572, 1.07963142, 1.07196223, 1.05250903, 1.03177639,
#         1.03879994, 1.03365315, 1.03752823, 1.03350326, 1.03166703,
#         1.03222159, 1.03705236, 1.03868757, 1.03998666, 1.03901252,
#         1.05132688, 1.05383732, 1.0506244 , 1.05319464, 1.04950845,
#         1.05117177, 1.04946072, 0.98307369, 1.01194323, 1.01589899,
#         1.01084144, 1.01713291, 1.02899324, 1.0456432 , 1.07196074,
#         1.09806748, 1.07854886, 1.07336863, 1.05074777, 1.03496891,
#         1.03204065, 1.03187157, 1.03099002, 1.03433879, 1.04056152,
#         1.03685366, 1.03481618, 1.03733434, 1.0374216 , 1.03534716,
#         1.03597991, 1.03419137, 1.03387522, 1.03640271, 1.0387693 ,
#         1.04005491, 1.02557322, 1.00786996, 0.96988156, 1.00647827,
#         1.0054607 , 0.99803781, 0.99882148, 1.01755065, 1.03887434,
#         1.05359225, 1.08576709, 1.07778303, 1.06122555, 1.03681991,
#         1.04034655, 1.05802428, 1.06610232, 1.06288641, 1.06505653,
#         1.06902372, 1.06703699, 1.06963876, 1.06870312, 1.06996274,
#         1.07673257, 1.076063  , 1.07434261, 1.07446494, 1.07864887,
#         1.07869766, 1.08437076, 1.08258748, 1.08075983, 0.99427648,
#         1.00134933, 0.99886146, 0.99730607, 1.00038711, 1.01428675,
#         1.02525258, 1.05714826, 1.07064313, 1.07325694, 1.05684781,
#         1.04247341, 1.06854138, 1.06828734, 1.0645451 , 1.0698726 ,
#         1.0717539 , 1.06894862, 1.07078118, 1.07407796, 1.07516888,
#         1.0779854 , 1.0766059 , 1.08258709, 1.07659755, 1.07637418,
#         1.06610912, 1.06496106, 1.0651415 , 1.05839361, 0.99334491,
#         0.99582552, 0.99598282, 0.99778112, 0.99474619, 1.00037805,
#         1.01610449, 1.05704564, 1.06024388, 1.05612475, 1.04906381,
#         1.05401213, 1.05765372, 1.05765718, 1.05912368, 1.05897769,
#         1.05758183, 1.05780053, 1.05956227, 1.06015751, 1.05702953,
#         1.05742782, 1.05751908, 1.06303684, 1.06186637, 1.0623548 ,
#         1.06090733, 1.05920117, 1.06050246, 1.06140307, 1.06598061,
#         0.95703288, 0.99755581, 0.99457527, 0.99182533, 0.99480692,
#         1.00577802, 1.0202929 , 1.05594427, 1.0645998 , 1.05594438,
#         1.03998515, 1.0399274 , 1.04301108, 1.04374163, 1.04341323,
#         1.04636181, 1.04540178, 1.04592351, 1.04585347, 1.0455679 ,
#         1.04278738, 1.04336637, 1.03752721, 1.03757371, 1.03571147,
#         1.03708161, 1.03341699, 1.03466626, 1.03524693, 1.03320593,
#         0.95773359, 0.99680765, 0.99090364, 0.98972956, 0.99049925,
#         1.0083787 , 1.01302706, 1.05067888, 1.05503163, 1.04319738,
#         1.0186268 , 1.00502104, 1.00353403, 1.00283839, 0.9955136 ,
#         0.99537024, 0.99433342, 0.98823131, 0.98682243, 0.98449105,
#         0.98206422, 0.97937143, 0.97887093, 0.98170762, 0.97923127,
#         0.97879756, 0.98276785, 0.98222242, 0.97976639, 0.97753502]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
df_best_model = get_best_model(score, 'AIC')
# Out:
# Best model: 0 with lowest AIC score: 13215.034595333196

# %%
df_best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                 1462
# Model:             ExponentialSmoothing   SSE                        7425392.036
# Optimized:                         True   AIC                          13215.035
# Trend:                         Additive   BIC                          15171.432
# Seasonal:                      Additive   AICC                         13469.867
# Seasonal Periods:                   365   Date:                 Thu, 06 Oct 2022
# Box-Cox:                           True   Time:                         08:06:59
# Box-Cox Coeff.:                -4.09228
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.8535714                alpha                 True
# smoothing_trend                   0.0001                 beta                 True
# smoothing_seasonal                0.0001                gamma                 True
# initial_level                  0.2443627                  l.0                 True
# initial_trend                 1.6744e-17                  b.0                 True
# damping_trend                  0.9900000                  phi                 True
# initial_seasons.0            -2.4364e-16                  s.0                 True
# initial_seasons.1            -1.7888e-16                  s.1                 True
# initial_seasons.2             1.1718e-16                  s.2                 True
# initial_seasons.3             9.8678e-17                  s.3                 True
# initial_seasons.4             2.4663e-17                  s.4                 True
# initial_seasons.5             1.5411e-17                  s.5                 True
# initial_seasons.6             5.2419e-17                  s.6                 True
# initial_seasons.7             1.3569e-16                  s.7                 True
# initial_seasons.8             1.2643e-16                  s.8                 True
# initial_seasons.9             4.0399e-16                  s.9                 True
# initial_seasons.10            3.9474e-16                 s.10                 True
# initial_seasons.11             4.595e-16                 s.11                 True
# initial_seasons.12            2.8372e-16                 s.12                 True
# initial_seasons.13           -2.1596e-17                 s.13                 True
# initial_seasons.14            1.5411e-17                 s.14                 True
# initial_seasons.15            3.3915e-17                 s.15                 True
# initial_seasons.16            5.2419e-17                 s.16                 True
# initial_seasons.17            8.0174e-17                 s.17                 True
# initial_seasons.18            7.0922e-17                 s.18                 True
# initial_seasons.19            2.4663e-17                 s.19                 True
# initial_seasons.20            4.3167e-17                 s.20                 True
# initial_seasons.21            4.3167e-17                 s.21                 True
# initial_seasons.22            7.0922e-17                 s.22                 True
# initial_seasons.23            5.2419e-17                 s.23                 True
# initial_seasons.24            8.9426e-17                 s.24                 True
# initial_seasons.25            4.3167e-17                 s.25                 True
# initial_seasons.26            5.2419e-17                 s.26                 True
# initial_seasons.27            2.4663e-17                 s.27                 True
# initial_seasons.28            1.5411e-17                 s.28                 True
# initial_seasons.29            4.3167e-17                 s.29                 True
# initial_seasons.30            6.1671e-17                 s.30                 True
# initial_seasons.31            9.8678e-17                 s.31                 True
# initial_seasons.32           -2.5289e-16                 s.32                 True
# initial_seasons.33            1.1718e-16                 s.33                 True
# initial_seasons.34            1.0793e-16                 s.34                 True
# initial_seasons.35           -3.0924e-18                 s.35                 True
# initial_seasons.36           -4.9352e-17                 s.36                 True
# initial_seasons.37            5.2419e-17                 s.37                 True
# initial_seasons.38            1.1718e-16                 s.38                 True
# initial_seasons.39            5.2419e-17                 s.39                 True
# initial_seasons.40            2.9297e-16                 s.40                 True
# initial_seasons.41            4.2249e-16                 s.41                 True
# initial_seasons.42            4.3174e-16                 s.42                 True
# initial_seasons.43            2.5596e-16                 s.43                 True
# initial_seasons.44            4.3167e-17                 s.44                 True
# initial_seasons.45            8.9426e-17                 s.45                 True
# initial_seasons.46            1.2643e-16                 s.46                 True
# initial_seasons.47            2.0045e-16                 s.47                 True
# initial_seasons.48            2.0045e-16                 s.48                 True
# initial_seasons.49             1.912e-16                 s.49                 True
# initial_seasons.50            2.0045e-16                 s.50                 True
# initial_seasons.51            2.0045e-16                 s.51                 True
# initial_seasons.52            1.4494e-16                 s.52                 True
# initial_seasons.53            1.5419e-16                 s.53                 True
# initial_seasons.54            1.6344e-16                 s.54                 True
# initial_seasons.55            1.7269e-16                 s.55                 True
# initial_seasons.56            1.7269e-16                 s.56                 True
# initial_seasons.57             1.912e-16                 s.57                 True
# initial_seasons.58            1.7269e-16                 s.58                 True
# initial_seasons.59            1.3569e-16                 s.59                 True
# initial_seasons.60           -2.2514e-16                 s.60                 True
# initial_seasons.61            2.4663e-17                 s.61                 True
# initial_seasons.62            2.4663e-17                 s.62                 True
# initial_seasons.63           -6.7855e-17                 s.63                 True
# initial_seasons.64           -7.7107e-17                 s.64                 True
# initial_seasons.65           -3.0848e-17                 s.65                 True
# initial_seasons.66            4.3167e-17                 s.66                 True
# initial_seasons.67            5.2419e-17                 s.67                 True
# initial_seasons.68            2.9297e-16                 s.68                 True
# initial_seasons.69            3.9474e-16                 s.69                 True
# initial_seasons.70            3.7623e-16                 s.70                 True
# initial_seasons.71             2.282e-16                 s.71                 True
# initial_seasons.72           -9.5611e-17                 s.72                 True
# initial_seasons.73           -1.4187e-16                 s.73                 True
# initial_seasons.74           -2.0663e-16                 s.74                 True
# initial_seasons.75           -1.2337e-16                 s.75                 True
# initial_seasons.76           -1.2337e-16                 s.76                 True
# initial_seasons.77           -1.2337e-16                 s.77                 True
# initial_seasons.78           -1.0486e-16                 s.78                 True
# initial_seasons.79           -1.0486e-16                 s.79                 True
# initial_seasons.80           -4.9352e-17                 s.80                 True
# initial_seasons.81           -3.0924e-18                 s.81                 True
# initial_seasons.82            3.3915e-17                 s.82                 True
# initial_seasons.83            1.5411e-17                 s.83                 True
# initial_seasons.84            3.3915e-17                 s.84                 True
# initial_seasons.85            2.4663e-17                 s.85                 True
# initial_seasons.86            6.1595e-18                 s.86                 True
# initial_seasons.87           -3.0848e-17                 s.87                 True
# initial_seasons.88           -6.7855e-17                 s.88                 True
# initial_seasons.89           -7.7107e-17                 s.89                 True
# initial_seasons.90           -1.2337e-16                 s.90                 True
# initial_seasons.91           -2.5289e-16                 s.91                 True
# initial_seasons.92           -6.7855e-17                 s.92                 True
# initial_seasons.93             -4.01e-17                 s.93                 True
# initial_seasons.94           -1.2344e-17                 s.94                 True
# initial_seasons.95           -1.6037e-16                 s.95                 True
# initial_seasons.96           -9.5611e-17                 s.96                 True
# initial_seasons.97            1.5411e-17                 s.97                 True
# initial_seasons.98           -1.2344e-17                 s.98                 True
# initial_seasons.99            3.8549e-16                 s.99                 True
# initial_seasons.100           3.5773e-16                s.100                 True
# initial_seasons.101           3.7623e-16                s.101                 True
# initial_seasons.102           2.7446e-16                s.102                 True
# initial_seasons.103           3.3915e-17                s.103                 True
# initial_seasons.104           4.3167e-17                s.104                 True
# initial_seasons.105           4.3167e-17                s.105                 True
# initial_seasons.106           3.3915e-17                s.106                 True
# initial_seasons.107           1.5411e-17                s.107                 True
# initial_seasons.108           4.3167e-17                s.108                 True
# initial_seasons.109           5.2419e-17                s.109                 True
# initial_seasons.110           3.3915e-17                s.110                 True
# initial_seasons.111           1.5411e-17                s.111                 True
# initial_seasons.112           1.5411e-17                s.112                 True
# initial_seasons.113          -2.1596e-17                s.113                 True
# initial_seasons.114          -3.0924e-18                s.114                 True
# initial_seasons.115          -3.0924e-18                s.115                 True
# initial_seasons.116            -4.01e-17                s.116                 True
# initial_seasons.117            -4.01e-17                s.117                 True
# initial_seasons.118          -2.1596e-17                s.118                 True
# initial_seasons.119          -6.7855e-17                s.119                 True
# initial_seasons.120          -1.0486e-16                s.120                 True
# initial_seasons.121          -2.6214e-16                s.121                 True
# initial_seasons.122          -6.7855e-17                s.122                 True
# initial_seasons.123          -1.1411e-16                s.123                 True
# initial_seasons.124          -1.2337e-16                s.124                 True
# initial_seasons.125          -1.7888e-16                s.125                 True
# initial_seasons.126           4.3167e-17                s.126                 True
# initial_seasons.127          -4.9352e-17                s.127                 True
# initial_seasons.128           1.0793e-16                s.128                 True
# initial_seasons.129           3.5773e-16                s.129                 True
# initial_seasons.130           3.5773e-16                s.130                 True
# initial_seasons.131           3.1147e-16                s.131                 True
# initial_seasons.132           2.1895e-16                s.132                 True
# initial_seasons.133          -3.0924e-18                s.133                 True
# initial_seasons.134            -4.01e-17                s.134                 True
# initial_seasons.135          -1.1411e-16                s.135                 True
# initial_seasons.136          -1.4187e-16                s.136                 True
# initial_seasons.137          -6.7855e-17                s.137                 True
# initial_seasons.138            -4.01e-17                s.138                 True
# initial_seasons.139          -3.0848e-17                s.139                 True
# initial_seasons.140          -4.9352e-17                s.140                 True
# initial_seasons.141          -6.7855e-17                s.141                 True
# initial_seasons.142          -8.6359e-17                s.142                 True
# initial_seasons.143            -4.01e-17                s.143                 True
# initial_seasons.144          -4.9352e-17                s.144                 True
# initial_seasons.145          -7.7107e-17                s.145                 True
# initial_seasons.146          -4.9352e-17                s.146                 True
# initial_seasons.147          -4.9352e-17                s.147                 True
# initial_seasons.148          -8.6359e-17                s.148                 True
# initial_seasons.149          -5.8604e-17                s.149                 True
# initial_seasons.150          -5.8604e-17                s.150                 True
# initial_seasons.151            -4.01e-17                s.151                 True
# initial_seasons.152          -1.8813e-16                s.152                 True
# initial_seasons.153          -1.2344e-17                s.153                 True
# initial_seasons.154          -8.6359e-17                s.154                 True
# initial_seasons.155          -1.5112e-16                s.155                 True
# initial_seasons.156          -6.7855e-17                s.156                 True
# initial_seasons.157           3.3915e-17                s.157                 True
# initial_seasons.158          -8.6359e-17                s.158                 True
# initial_seasons.159           6.1671e-17                s.159                 True
# initial_seasons.160           3.2997e-16                s.160                 True
# initial_seasons.161           2.8372e-16                s.161                 True
# initial_seasons.162           2.6521e-16                s.162                 True
# initial_seasons.163           1.5419e-16                s.163                 True
# initial_seasons.164          -2.1596e-17                s.164                 True
# initial_seasons.165           3.3915e-17                s.165                 True
# initial_seasons.166          -2.1596e-17                s.166                 True
# initial_seasons.167          -3.0848e-17                s.167                 True
# initial_seasons.168            -4.01e-17                s.168                 True
# initial_seasons.169          -5.8604e-17                s.169                 True
# initial_seasons.170          -6.7855e-17                s.170                 True
# initial_seasons.171            -4.01e-17                s.171                 True
# initial_seasons.172          -4.9352e-17                s.172                 True
# initial_seasons.173          -1.2344e-17                s.173                 True
# initial_seasons.174          -1.2344e-17                s.174                 True
# initial_seasons.175          -3.0924e-18                s.175                 True
# initial_seasons.176          -1.2344e-17                s.176                 True
# initial_seasons.177          -5.8604e-17                s.177                 True
# initial_seasons.178          -4.9352e-17                s.178                 True
# initial_seasons.179          -5.8604e-17                s.179                 True
# initial_seasons.180          -4.9352e-17                s.180                 True
# initial_seasons.181          -5.8604e-17                s.181                 True
# initial_seasons.182          -4.9344e-16                s.182                 True
# initial_seasons.183          -1.6037e-16                s.183                 True
# initial_seasons.184           2.4663e-17                s.184                 True
# initial_seasons.185          -1.2344e-17                s.185                 True
# initial_seasons.186           6.1671e-17                s.186                 True
# initial_seasons.187           7.0922e-17                s.187                 True
# initial_seasons.188           8.0174e-17                s.188                 True
# initial_seasons.189           3.3915e-17                s.189                 True
# initial_seasons.190           3.2072e-16                s.190                 True
# initial_seasons.191            1.912e-16                s.191                 True
# initial_seasons.192           2.0045e-16                s.192                 True
# initial_seasons.193          -1.1411e-16                s.193                 True
# initial_seasons.194           2.4663e-17                s.194                 True
# initial_seasons.195           6.1595e-18                s.195                 True
# initial_seasons.196          -1.2344e-17                s.196                 True
# initial_seasons.197           6.1595e-18                s.197                 True
# initial_seasons.198          -3.0924e-18                s.198                 True
# initial_seasons.199           2.4663e-17                s.199                 True
# initial_seasons.200           2.4663e-17                s.200                 True
# initial_seasons.201          -1.2344e-17                s.201                 True
# initial_seasons.202           1.5411e-17                s.202                 True
# initial_seasons.203           2.4663e-17                s.203                 True
# initial_seasons.204           3.3915e-17                s.204                 True
# initial_seasons.205           3.3915e-17                s.205                 True
# initial_seasons.206           3.3915e-17                s.206                 True
# initial_seasons.207           3.3915e-17                s.207                 True
# initial_seasons.208           5.2419e-17                s.208                 True
# initial_seasons.209           7.0922e-17                s.209                 True
# initial_seasons.210           7.0922e-17                s.210                 True
# initial_seasons.211          -9.5611e-17                s.211                 True
# initial_seasons.212          -3.2691e-16                s.212                 True
# initial_seasons.213          -6.1372e-16                s.213                 True
# initial_seasons.214          -1.3262e-16                s.214                 True
# initial_seasons.215          -4.9352e-17                s.215                 True
# initial_seasons.216          -1.3262e-16                s.216                 True
# initial_seasons.217          -9.5611e-17                s.217                 True
# initial_seasons.218           3.3915e-17                s.218                 True
# initial_seasons.219           1.4494e-16                s.219                 True
# initial_seasons.220          -6.7855e-17                s.220                 True
# initial_seasons.221           2.9297e-16                s.221                 True
# initial_seasons.222            2.282e-16                s.222                 True
# initial_seasons.223           1.4494e-16                s.223                 True
# initial_seasons.224          -2.0663e-16                s.224                 True
# initial_seasons.225          -1.7888e-16                s.225                 True
# initial_seasons.226          -2.1596e-17                s.226                 True
# initial_seasons.227          -3.0924e-18                s.227                 True
# initial_seasons.228          -3.0924e-18                s.228                 True
# initial_seasons.229           4.3167e-17                s.229                 True
# initial_seasons.230           8.0174e-17                s.230                 True
# initial_seasons.231           7.0922e-17                s.231                 True
# initial_seasons.232           8.9426e-17                s.232                 True
# initial_seasons.233           8.9426e-17                s.233                 True
# initial_seasons.234           8.0174e-17                s.234                 True
# initial_seasons.235           8.0174e-17                s.235                 True
# initial_seasons.236           8.0174e-17                s.236                 True
# initial_seasons.237           5.2419e-17                s.237                 True
# initial_seasons.238           4.3167e-17                s.238                 True
# initial_seasons.239           5.2419e-17                s.239                 True
# initial_seasons.240           4.3167e-17                s.240                 True
# initial_seasons.241           1.4494e-16                s.241                 True
# initial_seasons.242           1.2643e-16                s.242                 True
# initial_seasons.243           1.0793e-16                s.243                 True
# initial_seasons.244          -1.8813e-16                s.244                 True
# initial_seasons.245          -1.8813e-16                s.245                 True
# initial_seasons.246          -1.2337e-16                s.246                 True
# initial_seasons.247          -1.3262e-16                s.247                 True
# initial_seasons.248          -1.0486e-16                s.248                 True
# initial_seasons.249          -1.2344e-17                s.249                 True
# initial_seasons.250           6.1595e-18                s.250                 True
# initial_seasons.251          -3.0848e-17                s.251                 True
# initial_seasons.252           9.8678e-17                s.252                 True
# initial_seasons.253           1.8194e-16                s.253                 True
# initial_seasons.254           1.0793e-16                s.254                 True
# initial_seasons.255          -1.2337e-16                s.255                 True
# initial_seasons.256            1.912e-16                s.256                 True
# initial_seasons.257            1.912e-16                s.257                 True
# initial_seasons.258           1.4494e-16                s.258                 True
# initial_seasons.259           1.2643e-16                s.259                 True
# initial_seasons.260           1.7269e-16                s.260                 True
# initial_seasons.261           1.8194e-16                s.261                 True
# initial_seasons.262           1.8194e-16                s.262                 True
# initial_seasons.263           1.6344e-16                s.263                 True
# initial_seasons.264            1.912e-16                s.264                 True
# initial_seasons.265           2.1895e-16                s.265                 True
# initial_seasons.266            2.097e-16                s.266                 True
# initial_seasons.267            2.282e-16                s.267                 True
# initial_seasons.268            2.282e-16                s.268                 True
# initial_seasons.269           2.1895e-16                s.269                 True
# initial_seasons.270           1.4494e-16                s.270                 True
# initial_seasons.271           1.6344e-16                s.271                 True
# initial_seasons.272           1.4494e-16                s.272                 True
# initial_seasons.273           1.1718e-16                s.273                 True
# initial_seasons.274          -1.3262e-16                s.274                 True
# initial_seasons.275          -2.0663e-16                s.275                 True
# initial_seasons.276          -1.1411e-16                s.276                 True
# initial_seasons.277          -8.6359e-17                s.277                 True
# initial_seasons.278          -1.3262e-16                s.278                 True
# initial_seasons.279          -1.6037e-16                s.279                 True
# initial_seasons.280          -1.5112e-16                s.280                 True
# initial_seasons.281           5.2419e-17                s.281                 True
# initial_seasons.282           8.9426e-17                s.282                 True
# initial_seasons.283           8.9426e-17                s.283                 True
# initial_seasons.284           8.9426e-17                s.284                 True
# initial_seasons.285           1.4494e-16                s.285                 True
# initial_seasons.286           1.2643e-16                s.286                 True
# initial_seasons.287           9.8678e-17                s.287                 True
# initial_seasons.288           1.2643e-16                s.288                 True
# initial_seasons.289           1.1718e-16                s.289                 True
# initial_seasons.290           9.8678e-17                s.290                 True
# initial_seasons.291           1.0793e-16                s.291                 True
# initial_seasons.292           9.8678e-17                s.292                 True
# initial_seasons.293           1.1718e-16                s.293                 True
# initial_seasons.294           9.8678e-17                s.294                 True
# initial_seasons.295           9.8678e-17                s.295                 True
# initial_seasons.296           8.9426e-17                s.296                 True
# initial_seasons.297           1.0793e-16                s.297                 True
# initial_seasons.298           8.9426e-17                s.298                 True
# initial_seasons.299           8.9426e-17                s.299                 True
# initial_seasons.300           7.0922e-17                s.300                 True
# initial_seasons.301           9.8678e-17                s.301                 True
# initial_seasons.302           9.8678e-17                s.302                 True
# initial_seasons.303           7.0922e-17                s.303                 True
# initial_seasons.304           6.1671e-17                s.304                 True
# initial_seasons.305          -7.3399e-16                s.305                 True
# initial_seasons.306          -1.4187e-16                s.306                 True
# initial_seasons.307          -7.7107e-17                s.307                 True
# initial_seasons.308          -7.7107e-17                s.308                 True
# initial_seasons.309          -1.1411e-16                s.309                 True
# initial_seasons.310          -7.7107e-17                s.310                 True
# initial_seasons.311          -6.7855e-17                s.311                 True
# initial_seasons.312           5.2419e-17                s.312                 True
# initial_seasons.313           1.6344e-16                s.313                 True
# initial_seasons.314           1.0793e-16                s.314                 True
# initial_seasons.315            -4.01e-17                s.315                 True
# initial_seasons.316          -8.6359e-17                s.316                 True
# initial_seasons.317          -4.9352e-17                s.317                 True
# initial_seasons.318          -5.8604e-17                s.318                 True
# initial_seasons.319          -1.2344e-17                s.319                 True
# initial_seasons.320           1.5411e-17                s.320                 True
# initial_seasons.321          -3.0924e-18                s.321                 True
# initial_seasons.322          -3.0848e-17                s.322                 True
# initial_seasons.323            -4.01e-17                s.323                 True
# initial_seasons.324            -4.01e-17                s.324                 True
# initial_seasons.325          -5.8604e-17                s.325                 True
# initial_seasons.326          -4.9352e-17                s.326                 True
# initial_seasons.327          -1.3262e-16                s.327                 True
# initial_seasons.328          -1.4187e-16                s.328                 True
# initial_seasons.329          -1.4187e-16                s.329                 True
# initial_seasons.330          -1.4187e-16                s.330                 True
# initial_seasons.331          -1.5112e-16                s.331                 True
# initial_seasons.332          -1.6037e-16                s.332                 True
# initial_seasons.333          -2.0663e-16                s.333                 True
# initial_seasons.334          -2.3439e-16                s.334                 True
# initial_seasons.335          -7.8025e-16                s.335                 True
# initial_seasons.336          -1.1411e-16                s.336                 True
# initial_seasons.337          -1.0486e-16                s.337                 True
# initial_seasons.338          -6.7855e-17                s.338                 True
# initial_seasons.339          -1.3262e-16                s.339                 True
# initial_seasons.340           4.3167e-17                s.340                 True
# initial_seasons.341          -1.2337e-16                s.341                 True
# initial_seasons.342          -3.0924e-18                s.342                 True
# initial_seasons.343           1.5419e-16                s.343                 True
# initial_seasons.344           8.0174e-17                s.344                 True
# initial_seasons.345          -1.8813e-16                s.345                 True
# initial_seasons.346          -3.6391e-16                s.346                 True
# initial_seasons.347          -3.6391e-16                s.347                 True
# initial_seasons.348          -3.4541e-16                s.348                 True
# initial_seasons.349          -4.4718e-16                s.349                 True
# initial_seasons.350          -4.2868e-16                s.350                 True
# initial_seasons.351          -3.9167e-16                s.351                 True
# initial_seasons.352          -4.2868e-16                s.352                 True
# initial_seasons.353          -4.4718e-16                s.353                 True
# initial_seasons.354          -4.4718e-16                s.354                 True
# initial_seasons.355          -4.3793e-16                s.355                 True
# initial_seasons.356          -4.4718e-16                s.356                 True
# initial_seasons.357          -4.4718e-16                s.357                 True
# initial_seasons.358          -4.1943e-16                s.358                 True
# initial_seasons.359          -4.1943e-16                s.359                 True
# initial_seasons.360          -4.1943e-16                s.360                 True
# initial_seasons.361          -3.4541e-16                s.361                 True
# initial_seasons.362          -2.9915e-16                s.362                 True
# initial_seasons.363          -2.8065e-16                s.363                 True
# initial_seasons.364          -2.8065e-16                s.364                 True
# ----------------------------------------------------------------------------------
# """

# %%
plot_forecast(df_best_model, '2016', df_train['price'], df_test['price'])

# %%
score[0]
# Out:
# {'trend': 'add',
#  'damped': True,
#  'AIC': 13215.034595333196,
#  'BIC': 15171.432032247794,
#  'AICc': 13469.866551256062,
#  'model': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x1cf7c70cfd0>}

# %%
future = df_best_model.forecast(30)

# %%
pd.Series(future).plot()
# Out:
# <AxesSubplot:>

# %%
df_train
# Out:
#               price  one_diff  two_diff       log       sqrt  cube_root  \
# date
# 2016-01-01  2252.60       NaN       NaN  7.719840  47.461563  13.108752
# 2016-01-02  2454.50    201.90       NaN  7.805678  49.542911  13.489246
# 2016-01-03  2708.10    253.60       NaN  7.904003  52.039408  13.938677
# 2016-01-04  2577.80   -130.30       NaN  7.854692  50.772040  13.711440
# 2016-01-05  2597.75     19.95       NaN  7.862401  50.968127  13.746721
# ...             ...       ...       ...       ...        ...        ...
# 2019-12-28  3464.20     -4.70      -2.2  8.150237  58.857455  15.131001
# 2019-12-29  3464.20      0.00       0.0  8.150237  58.857455  15.131001
# 2019-12-30  3469.40      5.20       5.2  8.151737  58.901613  15.138568
# 2019-12-31  3477.30      7.90      17.8  8.154011  58.968636  15.150050
# 2020-01-01  3477.60      0.30      -6.4  8.154098  58.971179  15.150485
#
#             log_sqrt  subtract_MA  seasonal_decomp      cyclic   box_cox
# date
# 2016-01-01  3.859920          NaN              NaN -360.016743  0.057941
# 2016-01-02  3.902839          NaN              NaN -154.997367  0.057941
# 2016-01-03  3.952001          NaN              NaN  101.947020  0.057941
# 2016-01-04  3.927346          NaN              NaN  -24.461699  0.057941
# 2016-01-05  3.931200          NaN              NaN    0.184643  0.057941
# ...              ...          ...              ...         ...       ...
# 2019-12-28  4.075119   318.958630      -187.040548 -149.324336  0.057941
# 2019-12-29  4.075119   317.327945      -190.265205 -182.967003  0.057941
# 2019-12-30  4.075868   320.883014      -188.282740 -212.239033  0.057941
# 2019-12-31  4.077006   327.089315      -184.305753 -239.209998  0.057941
# 2020-01-01  4.077049   325.713151      -185.718356 -273.616820  0.057941
#
# [1462 rows x 11 columns]

# %% [markdown]
# ### Trial 3

# %%
trend = ['add', 'mul']
damped = [True, False]
seasonal = ['add', 'mul']
use_boxcox = [True, False, -2.19]
initialization_method = ['estimated','heuristic','legacy-heuristic']
df_ex_comb = combinator([trend, damped, seasonal, use_boxcox, initialization_method])

# %%
dfs = ['price','log','sqrt','log_sqrt','cube_root']
score = {}
for i, (t, dp,s,b,im) in enumerate(df_ex_comb):
    for df in dfs:
        train = df_train[df].dropna().values.ravel()
        y = df_test[df].dropna().values.ravel()
        exp = ExponentialSmoothing(train, 
                         trend=t, 
                         damped_trend=dp,
                         seasonal=s,
                          seasonal_periods=365,
                          use_boxcox=b,
                          initialization_method=im)
        model = exp.fit(use_brute=True, optimized=True)    
        y_hat = model.forecast(len(y))
        score[i] = {'trend':t, 
                    'damped':dp,
                    'AIC':model.aic,
                    'BIC':model.bic, 
                    'AICc':model.aicc, 
                    'RMSPE': rmspe(y, y_hat),
                    #'RMSE' : rmse(y, y_hat),
                    #'MAPE' : mape(y, y_hat),
                    'model': model}

# %%
df_best_model = get_best_model(score, 'AIC')
# Out:
# Best model: 30 with lowest AIC score: -5802.679011258396

# %%
df_best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                 1462
# Model:             ExponentialSmoothing   SSE                             16.673
# Optimized:                         True   AIC                          -5802.679
# Trend:                         Additive   BIC                          -3851.569
# Seasonal:                Multiplicative   AICC                         -5549.446
# Seasonal Periods:                   365   Date:                 Thu, 06 Oct 2022
# Box-Cox:                          False   Time:                         08:27:15
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.9634462                alpha                 True
# smoothing_trend               9.0935e-05                 beta                 True
# smoothing_seasonal             8.204e-05                gamma                 True
# initial_level                  13.253654                  l.0                 True
# initial_trend                  0.0013211                  b.0                 True
# initial_seasons.0              0.9925659                  s.0                 True
# initial_seasons.1              0.9984219                  s.1                 True
# initial_seasons.2              1.0152808                  s.2                 True
# initial_seasons.3              1.0096670                  s.3                 True
# initial_seasons.4              1.0071820                  s.4                 True
# initial_seasons.5              1.0073962                  s.5                 True
# initial_seasons.6              1.0172334                  s.6                 True
# initial_seasons.7              1.0201015                  s.7                 True
# initial_seasons.8              1.0192158                  s.8                 True
# initial_seasons.9              1.0312983                  s.9                 True
# initial_seasons.10             1.0282421                 s.10                 True
# initial_seasons.11             1.0253239                 s.11                 True
# initial_seasons.12             1.0121254                 s.12                 True
# initial_seasons.13             0.9967443                 s.13                 True
# initial_seasons.14             0.9984554                 s.14                 True
# initial_seasons.15             0.9988927                 s.15                 True
# initial_seasons.16             0.9992620                 s.16                 True
# initial_seasons.17             0.9995975                 s.17                 True
# initial_seasons.18             0.9987816                 s.18                 True
# initial_seasons.19             0.9985460                 s.19                 True
# initial_seasons.20             0.9988009                 s.20                 True
# initial_seasons.21             0.9986140                 s.21                 True
# initial_seasons.22             0.9991753                 s.22                 True
# initial_seasons.23             0.9989841                 s.23                 True
# initial_seasons.24             0.9997805                 s.24                 True
# initial_seasons.25             0.9997500                 s.25                 True
# initial_seasons.26             1.0000416                 s.26                 True
# initial_seasons.27             0.9994561                 s.27                 True
# initial_seasons.28             0.9992755                 s.28                 True
# initial_seasons.29             1.0003241                 s.29                 True
# initial_seasons.30             1.0006268                 s.30                 True
# initial_seasons.31             1.0015088                 s.31                 True
# initial_seasons.32             0.9914272                 s.32                 True
# initial_seasons.33             1.0088437                 s.33                 True
# initial_seasons.34             1.0083372                 s.34                 True
# initial_seasons.35             1.0047190                 s.35                 True
# initial_seasons.36             0.9996606                 s.36                 True
# initial_seasons.37             1.0072077                 s.37                 True
# initial_seasons.38             1.0154306                 s.38                 True
# initial_seasons.39             1.0123065                 s.39                 True
# initial_seasons.40             1.0238177                 s.40                 True
# initial_seasons.41             1.0241946                 s.41                 True
# initial_seasons.42             1.0178051                 s.42                 True
# initial_seasons.43             1.0115358                 s.43                 True
# initial_seasons.44             0.9998648                 s.44                 True
# initial_seasons.45             1.0017044                 s.45                 True
# initial_seasons.46             1.0027147                 s.46                 True
# initial_seasons.47             1.0046572                 s.47                 True
# initial_seasons.48             1.0041244                 s.48                 True
# initial_seasons.49             1.0056695                 s.49                 True
# initial_seasons.50             1.0054632                 s.50                 True
# initial_seasons.51             1.0043924                 s.51                 True
# initial_seasons.52             1.0020718                 s.52                 True
# initial_seasons.53             1.0027520                 s.53                 True
# initial_seasons.54             1.0048202                 s.54                 True
# initial_seasons.55             1.0040703                 s.55                 True
# initial_seasons.56             1.0035407                 s.56                 True
# initial_seasons.57             1.0039456                 s.57                 True
# initial_seasons.58             1.0038589                 s.58                 True
# initial_seasons.59             1.0028532                 s.59                 True
# initial_seasons.60             0.9893665                 s.60                 True
# initial_seasons.61             0.9927050                 s.61                 True
# initial_seasons.62             0.9988078                 s.62                 True
# initial_seasons.63             0.9959860                 s.63                 True
# initial_seasons.64             0.9968261                 s.64                 True
# initial_seasons.65             0.9958121                 s.65                 True
# initial_seasons.66             1.0035911                 s.66                 True
# initial_seasons.67             1.0078770                 s.67                 True
# initial_seasons.68             1.0194889                 s.68                 True
# initial_seasons.69             1.0179084                 s.69                 True
# initial_seasons.70             1.0173049                 s.70                 True
# initial_seasons.71             1.0118100                 s.71                 True
# initial_seasons.72             0.9948810                 s.72                 True
# initial_seasons.73             0.9924081                 s.73                 True
# initial_seasons.74             0.9911621                 s.74                 True
# initial_seasons.75             0.9929696                 s.75                 True
# initial_seasons.76             0.9958057                 s.76                 True
# initial_seasons.77             0.9940965                 s.77                 True
# initial_seasons.78             0.9954131                 s.78                 True
# initial_seasons.79             0.9955186                 s.79                 True
# initial_seasons.80             0.9970324                 s.80                 True
# initial_seasons.81             0.9999538                 s.81                 True
# initial_seasons.82             0.9991431                 s.82                 True
# initial_seasons.83             1.0002339                 s.83                 True
# initial_seasons.84             1.0011078                 s.84                 True
# initial_seasons.85             1.0013341                 s.85                 True
# initial_seasons.86             1.0007782                 s.86                 True
# initial_seasons.87             0.9999414                 s.87                 True
# initial_seasons.88             0.9997325                 s.88                 True
# initial_seasons.89             1.0005182                 s.89                 True
# initial_seasons.90             0.9995123                 s.90                 True
# initial_seasons.91             0.9859385                 s.91                 True
# initial_seasons.92             1.0001956                 s.92                 True
# initial_seasons.93             1.0066147                 s.93                 True
# initial_seasons.94             1.0020106                 s.94                 True
# initial_seasons.95             1.0035127                 s.95                 True
# initial_seasons.96             1.0087680                 s.96                 True
# initial_seasons.97             1.0166137                 s.97                 True
# initial_seasons.98             1.0175940                 s.98                 True
# initial_seasons.99             1.0325796                 s.99                 True
# initial_seasons.100            1.0263212                s.100                 True
# initial_seasons.101            1.0292878                s.101                 True
# initial_seasons.102            1.0235179                s.102                 True
# initial_seasons.103            1.0073813                s.103                 True
# initial_seasons.104            1.0072789                s.104                 True
# initial_seasons.105            1.0075138                s.105                 True
# initial_seasons.106            1.0072040                s.106                 True
# initial_seasons.107            1.0068737                s.107                 True
# initial_seasons.108            1.0077810                s.108                 True
# initial_seasons.109            1.0095640                s.109                 True
# initial_seasons.110            1.0086550                s.110                 True
# initial_seasons.111            1.0082288                s.111                 True
# initial_seasons.112            1.0080046                s.112                 True
# initial_seasons.113            1.0072720                s.113                 True
# initial_seasons.114            1.0074389                s.114                 True
# initial_seasons.115            1.0074163                s.115                 True
# initial_seasons.116            1.0066891                s.116                 True
# initial_seasons.117            1.0064072                s.117                 True
# initial_seasons.118            1.0072451                s.118                 True
# initial_seasons.119            1.0079436                s.119                 True
# initial_seasons.120            1.0001419                s.120                 True
# initial_seasons.121            0.9881646                s.121                 True
# initial_seasons.122            1.0008425                s.122                 True
# initial_seasons.123            0.9997371                s.123                 True
# initial_seasons.124            1.0000839                s.124                 True
# initial_seasons.125            1.0020731                s.125                 True
# initial_seasons.126            1.0105871                s.126                 True
# initial_seasons.127            1.0124715                s.127                 True
# initial_seasons.128            1.0182687                s.128                 True
# initial_seasons.129            1.0269721                s.129                 True
# initial_seasons.130            1.0218484                s.130                 True
# initial_seasons.131            1.0176166                s.131                 True
# initial_seasons.132            1.0122050                s.132                 True
# initial_seasons.133            1.0049790                s.133                 True
# initial_seasons.134            1.0041378                s.134                 True
# initial_seasons.135            1.0026279                s.135                 True
# initial_seasons.136            1.0015205                s.136                 True
# initial_seasons.137            1.0020487                s.137                 True
# initial_seasons.138            1.0030871                s.138                 True
# initial_seasons.139            1.0015526                s.139                 True
# initial_seasons.140            1.0021846                s.140                 True
# initial_seasons.141            1.0015627                s.141                 True
# initial_seasons.142            1.0012732                s.142                 True
# initial_seasons.143            1.0026666                s.143                 True
# initial_seasons.144            1.0019028                s.144                 True
# initial_seasons.145            0.9999755                s.145                 True
# initial_seasons.146            1.0001090                s.146                 True
# initial_seasons.147            0.9993606                s.147                 True
# initial_seasons.148            0.9986421                s.148                 True
# initial_seasons.149            0.9998922                s.149                 True
# initial_seasons.150            1.0000780                s.150                 True
# initial_seasons.151            1.0009646                s.151                 True
# initial_seasons.152            0.9881089                s.152                 True
# initial_seasons.153            0.9964079                s.153                 True
# initial_seasons.154            0.9963106                s.154                 True
# initial_seasons.155            0.9972690                s.155                 True
# initial_seasons.156            1.0037970                s.156                 True
# initial_seasons.157            1.0047878                s.157                 True
# initial_seasons.158            1.0122738                s.158                 True
# initial_seasons.159            1.0189358                s.159                 True
# initial_seasons.160            1.0269328                s.160                 True
# initial_seasons.161            1.0202330                s.161                 True
# initial_seasons.162            1.0178939                s.162                 True
# initial_seasons.163            1.0118427                s.163                 True
# initial_seasons.164            1.0075656                s.164                 True
# initial_seasons.165            1.0095974                s.165                 True
# initial_seasons.166            1.0075751                s.166                 True
# initial_seasons.167            1.0086852                s.167                 True
# initial_seasons.168            1.0073747                s.168                 True
# initial_seasons.169            1.0068007                s.169                 True
# initial_seasons.170            1.0070564                s.170                 True
# initial_seasons.171            1.0084878                s.171                 True
# initial_seasons.172            1.0089594                s.172                 True
# initial_seasons.173            1.0092515                s.173                 True
# initial_seasons.174            1.0086980                s.174                 True
# initial_seasons.175            1.0123433                s.175                 True
# initial_seasons.176            1.0127748                s.176                 True
# initial_seasons.177            1.0115902                s.177                 True
# initial_seasons.178            1.0122492                s.178                 True
# initial_seasons.179            1.0110107                s.179                 True
# initial_seasons.180            1.0114505                s.180                 True
# initial_seasons.181            1.0109207                s.181                 True
# initial_seasons.182            0.9896878                s.182                 True
# initial_seasons.183            0.9997950                s.183                 True
# initial_seasons.184            1.0017343                s.184                 True
# initial_seasons.185            1.0000199                s.185                 True
# initial_seasons.186            1.0019302                s.186                 True
# initial_seasons.187            1.0053890                s.187                 True
# initial_seasons.188            1.0099725                s.188                 True
# initial_seasons.189            1.0168717                s.189                 True
# initial_seasons.190            1.0256820                s.190                 True
# initial_seasons.191            1.0197148                s.191                 True
# initial_seasons.192            1.0182967                s.192                 True
# initial_seasons.193            1.0105095                s.193                 True
# initial_seasons.194            1.0074076                s.194                 True
# initial_seasons.195            1.0066917                s.195                 True
# initial_seasons.196            1.0066262                s.196                 True
# initial_seasons.197            1.0063815                s.197                 True
# initial_seasons.198            1.0071387                s.198                 True
# initial_seasons.199            1.0090552                s.199                 True
# initial_seasons.200            1.0079925                s.200                 True
# initial_seasons.201            1.0073646                s.201                 True
# initial_seasons.202            1.0084377                s.202                 True
# initial_seasons.203            1.0087309                s.203                 True
# initial_seasons.204            1.0083161                s.204                 True
# initial_seasons.205            1.0087209                s.205                 True
# initial_seasons.206            1.0082563                s.206                 True
# initial_seasons.207            1.0080384                s.207                 True
# initial_seasons.208            1.0088303                s.208                 True
# initial_seasons.209            1.0095162                s.209                 True
# initial_seasons.210            1.0098187                s.210                 True
# initial_seasons.211            1.0049468                s.211                 True
# initial_seasons.212            0.9989138                s.212                 True
# initial_seasons.213            0.9869510                s.213                 True
# initial_seasons.214            0.9999035                s.214                 True
# initial_seasons.215            1.0003040                s.215                 True
# initial_seasons.216            0.9978368                s.216                 True
# initial_seasons.217            0.9980651                s.217                 True
# initial_seasons.218            1.0040843                s.218                 True
# initial_seasons.219            1.0103879                s.219                 True
# initial_seasons.220            1.0135441                s.220                 True
# initial_seasons.221            1.0242655                s.221                 True
# initial_seasons.222            1.0214697                s.222                 True
# initial_seasons.223            1.0161128                s.223                 True
# initial_seasons.224            1.0073796                s.224                 True
# initial_seasons.225            1.0084076                s.225                 True
# initial_seasons.226            1.0139756                s.226                 True
# initial_seasons.227            1.0162528                s.227                 True
# initial_seasons.228            1.0151900                s.228                 True
# initial_seasons.229            1.0160338                s.229                 True
# initial_seasons.230            1.0174518                s.230                 True
# initial_seasons.231            1.0169135                s.231                 True
# initial_seasons.232            1.0177465                s.232                 True
# initial_seasons.233            1.0173690                s.233                 True
# initial_seasons.234            1.0175951                s.234                 True
# initial_seasons.235            1.0191399                s.235                 True
# initial_seasons.236            1.0189022                s.236                 True
# initial_seasons.237            1.0181937                s.237                 True
# initial_seasons.238            1.0179756                s.238                 True
# initial_seasons.239            1.0189822                s.239                 True
# initial_seasons.240            1.0188095                s.240                 True
# initial_seasons.241            1.0216030                s.241                 True
# initial_seasons.242            1.0212281                s.242                 True
# initial_seasons.243            1.0208094                s.243                 True
# initial_seasons.244            0.9959366                s.244                 True
# initial_seasons.245            0.9985061                s.245                 True
# initial_seasons.246            0.9981591                s.246                 True
# initial_seasons.247            0.9975453                s.247                 True
# initial_seasons.248            0.9986401                s.248                 True
# initial_seasons.249            1.0030293                s.249                 True
# initial_seasons.250            1.0059635                s.250                 True
# initial_seasons.251            1.0145415                s.251                 True
# initial_seasons.252            1.0188030                s.252                 True
# initial_seasons.253            1.0197117                s.253                 True
# initial_seasons.254            1.0144596                s.254                 True
# initial_seasons.255            1.0092115                s.255                 True
# initial_seasons.256            1.0181903                s.256                 True
# initial_seasons.257            1.0178412                s.257                 True
# initial_seasons.258            1.0162984                s.258                 True
# initial_seasons.259            1.0172554                s.259                 True
# initial_seasons.260            1.0175439                s.260                 True
# initial_seasons.261            1.0163576                s.261                 True
# initial_seasons.262            1.0162480                s.262                 True
# initial_seasons.263            1.0164953                s.263                 True
# initial_seasons.264            1.0162311                s.264                 True
# initial_seasons.265            1.0165007                s.265                 True
# initial_seasons.266            1.0153306                s.266                 True
# initial_seasons.267            1.0163465                s.267                 True
# initial_seasons.268            1.0140887                s.268                 True
# initial_seasons.269            1.0133006                s.269                 True
# initial_seasons.270            1.0095088                s.270                 True
# initial_seasons.271            1.0088936                s.271                 True
# initial_seasons.272            1.0085281                s.272                 True
# initial_seasons.273            1.0061792                s.273                 True
# initial_seasons.274            0.9864650                s.274                 True
# initial_seasons.275            0.9868086                s.275                 True
# initial_seasons.276            0.9868519                s.276                 True
# initial_seasons.277            0.9871021                s.277                 True
# initial_seasons.278            0.9856284                s.278                 True
# initial_seasons.279            0.9867322                s.279                 True
# initial_seasons.280            0.9909682                s.280                 True
# initial_seasons.281            1.0028508                s.281                 True
# initial_seasons.282            1.0037656                s.282                 True
# initial_seasons.283            1.0023939                s.283                 True
# initial_seasons.284            1.0002654                s.284                 True
# initial_seasons.285            1.0017503                s.285                 True
# initial_seasons.286            1.0023357                s.286                 True
# initial_seasons.287            1.0019040                s.287                 True
# initial_seasons.288            1.0020528                s.288                 True
# initial_seasons.289            1.0013586                s.289                 True
# initial_seasons.290            1.0002104                s.290                 True
# initial_seasons.291            0.9997044                s.291                 True
# initial_seasons.292            0.9997723                s.292                 True
# initial_seasons.293            0.9994483                s.293                 True
# initial_seasons.294            0.9980241                s.294                 True
# initial_seasons.295            0.9977127                s.295                 True
# initial_seasons.296            0.9974387                s.296                 True
# initial_seasons.297            0.9987388                s.297                 True
# initial_seasons.298            0.9979401                s.298                 True
# initial_seasons.299            0.9977338                s.299                 True
# initial_seasons.300            0.9966903                s.300                 True
# initial_seasons.301            0.9960407                s.301                 True
# initial_seasons.302            0.9963833                s.302                 True
# initial_seasons.303            0.9964901                s.303                 True
# initial_seasons.304            0.9974762                s.304                 True
# initial_seasons.305            0.9639744                s.305                 True
# initial_seasons.306            0.9781404                s.306                 True
# initial_seasons.307            0.9776627                s.307                 True
# initial_seasons.308            0.9767559                s.308                 True
# initial_seasons.309            0.9774153                s.309                 True
# initial_seasons.310            0.9806727                s.310                 True
# initial_seasons.311            0.9846159                s.311                 True
# initial_seasons.312            0.9949061                s.312                 True
# initial_seasons.313            0.9977459                s.313                 True
# initial_seasons.314            0.9950351                s.314                 True
# initial_seasons.315            0.9897802                s.315                 True
# initial_seasons.316            0.9896296                s.316                 True
# initial_seasons.317            0.9907365                s.317                 True
# initial_seasons.318            0.9908402                s.318                 True
# initial_seasons.319            0.9910590                s.319                 True
# initial_seasons.320            0.9920021                s.320                 True
# initial_seasons.321            0.9916515                s.321                 True
# initial_seasons.322            0.9915211                s.322                 True
# initial_seasons.323            0.9915469                s.323                 True
# initial_seasons.324            0.9913999                s.324                 True
# initial_seasons.325            0.9905511                s.325                 True
# initial_seasons.326            0.9907384                s.326                 True
# initial_seasons.327            0.9886162                s.327                 True
# initial_seasons.328            0.9884760                s.328                 True
# initial_seasons.329            0.9878542                s.329                 True
# initial_seasons.330            0.9881498                s.330                 True
# initial_seasons.331            0.9871729                s.331                 True
# initial_seasons.332            0.9876856                s.332                 True
# initial_seasons.333            0.9878097                s.333                 True
# initial_seasons.334            0.9871009                s.334                 True
# initial_seasons.335            0.9644981                s.335                 True
# initial_seasons.336            0.9791310                s.336                 True
# initial_seasons.337            0.9778154                s.337                 True
# initial_seasons.338            0.9778658                s.338                 True
# initial_seasons.339            0.9781095                s.339                 True
# initial_seasons.340            0.9844859                s.340                 True
# initial_seasons.341            0.9855200                s.341                 True
# initial_seasons.342            0.9965772                s.342                 True
# initial_seasons.343            0.9995006                s.343                 True
# initial_seasons.344            0.9964605                s.344                 True
# initial_seasons.345            0.9890365                s.345                 True
# initial_seasons.346            0.9851558                s.346                 True
# initial_seasons.347            0.9856238                s.347                 True
# initial_seasons.348            0.9862937                s.348                 True
# initial_seasons.349            0.9843828                s.349                 True
# initial_seasons.350            0.9851491                s.350                 True
# initial_seasons.351            0.9857065                s.351                 True
# initial_seasons.352            0.9847714                s.352                 True
# initial_seasons.353            0.9850398                s.353                 True
# initial_seasons.354            0.9852053                s.354                 True
# initial_seasons.355            0.9851966                s.355                 True
# initial_seasons.356            0.9851173                s.356                 True
# initial_seasons.357            0.9856433                s.357                 True
# initial_seasons.358            0.9872857                s.358                 True
# initial_seasons.359            0.9874633                s.359                 True
# initial_seasons.360            0.9880626                s.360                 True
# initial_seasons.361            0.9904844                s.361                 True
# initial_seasons.362            0.9914330                s.362                 True
# initial_seasons.363            0.9916208                s.363                 True
# initial_seasons.364            0.9917003                s.364                 True
# ----------------------------------------------------------------------------------
# """

# %%
for df in dfs:
    plot_forecast(df_best_model, '2016', df_train[df], df_test[df])

# %%
plot_forecast(df_best_model, '2016', df_train['cube_root'], df_test['cube_root'])

# %%
score[30]
# Out:
# {'trend': 'add',
#  'damped': False,
#  'AIC': -5802.679011258396,
#  'BIC': -3851.5691349841077,
#  'AICc': -5549.44598373546,
#  'RMSPE': 0.36331834453539724,
#  'model': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x1cf7590eeb0>}

# %%
plot_forecast(df_best_model, '2016', df_train['cube_root'], df_test['cube_root'])

# %%
score[0]
# Out:
# {'trend': 'add',
#  'damped': True,
#  'AIC': -5486.691056953011,
#  'BIC': -3530.2936200384133,
#  'AICc': -5231.859101030146,
#  'RMSPE': 0.484691151001831,
#  'model': <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper at 0x1cf75762a90>}

# %% [markdown]
# ### Trial 4

# %%
scores=[]
hwf_model = ExponentialSmoothing(df_train['price'],trend='add',seasonal='mul',seasonal_periods=366).fit()
hwf_pred = hwf_model.predict(start=df_test.index[0],end=df_test.index[-1])
scores.append(mape(hwf_pred,df_test['price']))
scores.append(rmse(hwf_pred,df_test['price']))
scores.append(rmspe(hwf_pred,df_test['price']))
print('MAPE score for HOLT WINTERS MODEL is',scores[0])
print('RMSE score for HOLT WINTERS MODEL is',scores[1])
print('RMPSE score for HOLT WINTERS MODEL is',scores[2])
# Out:
# MAPE score for HOLT WINTERS MODEL is 0.13141773448557842
# RMSE score for HOLT WINTERS MODEL is 540.1237393638762
# RMPSE score for HOLT WINTERS MODEL is 1.444803334010187

# %%
plot_forecast(hwf_model,'2016',df_train['price'],df_test['price'])

# %% [markdown]
# ## ARIMA on original data

# %%
model = ARIMA(df_train['price'], order=(0,1,1))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 1462
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8472.571
# Date:                Thu, 06 Oct 2022   AIC                          16949.143
# Time:                        08:27:17   BIC                          16959.716
# Sample:                    01-01-2016   HQIC                         16953.087
#                          - 01-01-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0053      0.018     -0.299      0.765      -0.040       0.029
# sigma2      6377.0326     86.724     73.532      0.000    6207.056    6547.009
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             10293.87
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.41   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
(acorr_ljungbox(results.resid, 
                lags=26,
                return_df=True) < 0.05)['lb_pvalue'].sum()
# Out:
# 23

# %%
plot_acf(results.resid, zero=False);plt.show()

# %%
plot_forecast(results, '2016', df_train['price'], df_test['price'])

# %% [markdown]
# ARIMA(1, 0, 0) is a first-order autoregressive or AR(1) model
#
# ARIMA(1, 1, 0) is a differenced first-order autoregressive model
#
# ARIMA(0, 0, 1) is a first-order moving average or MA(1) model
#
# ARIMA(1, 0, 1) is an ARMA (1,1) model
#
# ARIMA(0, 1, 1) is a simple exponential smoothing model

# %%
pv, dv, qv = [list(range(3))]*3
vals = combinator([pv, dv, qv ])
score = {}
for i, (p, d, q) in enumerate(vals):
    m = ARIMA(df_train['price'], order=(p,d,q))
    res = m.fit()
    y = df_train['price'].values.ravel() 
    y_hat = res.forecast(steps=len(y))
    score[i] = {'order': (p,d,q),
                'AIC':res.aic, 
                'RMSPE': rmspe(y, y_hat),
                'BIC': res.bic,
                'AICc':res.aicc,
                'RMSE' : rmse(y, y_hat),
                'MAPE' : mape(y, y_hat),
                'model': res}
best_m = get_best_model(score, 'AIC')
# Out:
# Best model: 23 with lowest AIC score: 16798.917559289795

# %%
pd.DataFrame(score).T.sort_values(by='AIC').reset_index()
# Out:
#     index      order           AIC      RMSPE           BIC          AICc  \
# 0      23  (2, 1, 2)  16798.917559   2.375743  16825.351941  16798.958796
# 1      22  (2, 1, 1)  16825.416732   2.214646  16846.564237  16825.444204
# 2      14  (1, 1, 2)  16828.413376   2.210851  16849.560882  16828.440849
# 3      13  (1, 1, 1)  16838.943408   2.201944  16854.804037   16838.95988
# 4      20  (2, 0, 2)  16847.978518   1.532373  16879.703882   16848.03625
# 5       9  (1, 0, 0)  16931.925312   0.892821  16947.787993  16931.941772
# 6      18  (2, 0, 0)  16933.319859   0.890091  16954.470101  16933.347312
# 7      10  (1, 0, 1)  16933.324459   0.890128  16954.474702  16933.351913
# 8      11  (1, 0, 2)  16935.292427   0.889412   16961.73023  16935.333636
# 9      19  (2, 0, 1)  16935.323573   0.889919  16961.761376  16935.364782
# 10      7  (0, 2, 1)  16946.705242   4.836871  16957.277626  16946.713479
# 11      3  (0, 1, 0)  16947.181266   2.653355  16952.468142  16947.184007
# 12      8  (0, 2, 2)  16948.507363   4.697519  16964.365939  16948.523847
# 13     16  (1, 2, 1)  16948.519391   4.705829  16964.377966  16948.535874
# 14      4  (0, 1, 1)  16949.142515   2.653349  16959.716268  16949.150745
# 15     12  (1, 1, 0)  16949.144198    2.65335  16959.717951  16949.152428
# 16     25  (2, 2, 1)  16949.867585   4.687914  16971.012352  16949.895076
# 17      5  (0, 1, 2)  16950.187386   2.652477  16966.048015  16950.203858
# 18     21  (2, 1, 0)  16950.455036   2.652754  16966.315665  16950.471508
# 19     17  (1, 2, 2)  16950.553896   4.713722  16971.698663  16950.581388
# 20     26  (2, 2, 2)  16952.376578     4.6976  16978.807537  16952.417844
# 21     24  (2, 2, 0)  17399.885965   12.31077   17415.74454  17399.902449
# 22     15  (1, 2, 0)  17548.021129  10.100462  17558.593513  17548.029366
# 23      6  (0, 2, 0)  17953.134314   3.318338  17958.420506  17953.137058
# 24      2  (0, 0, 2)  18148.689433   0.827533  18169.839675  18148.716887
# 25      1  (0, 0, 1)  18877.235722    0.82486  18893.098404  18877.252183
# 26      0  (0, 0, 0)  20291.173761   0.821405  20301.748883  20291.181986
#
#            RMSE      MAPE                                              model
# 0    634.327713  0.217918  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 1    590.491775  0.202922  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 2    589.459184  0.202575  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 3    587.032626  0.201759  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 4    414.102002  0.131684  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 5    263.865193  0.066184  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 6    263.295674  0.066042  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 7     263.30336  0.066044  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 8    263.154534  0.066007  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 9    263.260084  0.066033  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 10  1350.797026  0.473312  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 11   710.119997  0.245585  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 12  1309.592645  0.459912  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 13  1312.049608  0.460713  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 14   710.118313  0.245584  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 15   710.118594  0.245585  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 16  1306.761238  0.458983  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 17   709.879589  0.245495  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 18   709.955461  0.245523  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 19  1314.381758  0.461474  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 20  1309.616373  0.459919  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 21  3560.761555  1.155207  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 22  2907.510504  0.956837  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 23   902.999188  0.321226  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 24   250.492779  0.062994  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 25   250.016606  0.062919  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 26   249.440216  0.062827  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...

# %%
plot_forecast(best_m, '2016', df_train['price'], df_test['price'])

# %%
# Hyperparameter tuning and trying ARIMA on all type of datasets (Original as well as Stationary data)
# Original dataset --> price
# Stationary data --> one_diff, two_diff, cyclic, seasonal_decomp, log, sqrt

pv, dv, qv = [list(range(3))]*3
vals = combinator([pv, dv, qv ])
score = {}
dfs = ['price','one_diff','two_diff','cyclic','seasonal_decomp','log','sqrt']
for i, (p, d, q) in enumerate(vals):
    for df in dfs:
        m = ARIMA(df_train[df].dropna(), order=(p,d,q))
        res = m.fit()
        y = df_train['one_diff'].dropna().values.ravel() 
        y_hat = res.forecast(steps=len(y))
        score[i] = {'order': (p,d,q),
                    'AIC':res.aic, 
                    'RMSPE': rmspe(y, y_hat),
                    'BIC': res.bic,
                    'AICc':res.aicc,
                    'RMSE' : rmse(y, y_hat),
                    'MAPE' : mape(y, y_hat),
                    'model': res}
best_m = get_best_model(score, 'AIC')
# Out:
# Best model: 23 with lowest AIC score: 3136.396961386947

# %%
pd.DataFrame(score).T.sort_values(by='AIC').reset_index()
# Out:
#     index      order          AIC        RMSPE          BIC         AICc  \
# 0      23  (2, 1, 2)  3136.396961   866.418757  3162.831343  3136.438199
# 1      22  (2, 1, 1)  3159.745466   860.920027  3180.892971  3159.772938
# 2      14  (1, 1, 2)  3162.064358   860.780895  3183.211863   3162.09183
# 3      13  (1, 1, 1)  3170.917491   860.412673   3186.77812  3170.933963
# 4       9  (1, 0, 0)  3257.522417   788.679667  3273.385099  3257.538878
# 5      10  (1, 0, 1)  3259.359948   788.624259   3280.51019  3259.387401
# 6      18  (2, 0, 0)  3259.362441   788.665522  3280.512683  3259.389894
# 7      11  (1, 0, 2)  3261.261514   788.688776  3287.699317  3261.302722
# 8      19  (2, 0, 1)  3261.285552   788.710205  3287.723355   3261.32676
# 9      20  (2, 0, 2)  3263.286295   788.640319  3295.011659  3263.344027
# 10      3  (0, 1, 0)  3282.868134   877.645412   3288.15501  3282.870875
# 11      5  (0, 1, 2)  3284.236102   877.593024  3300.096731  3284.252574
# 12      4  (0, 1, 1)  3284.492761   877.644502  3295.066514  3284.500991
# 13     12  (1, 1, 0)  3284.517936   877.644835  3295.091689  3284.526167
# 14     21  (2, 1, 0)  3284.938506   877.612207  3300.799135  3284.954978
# 15      7  (0, 2, 1)  3290.745429    980.13299  3301.317813  3290.753665
# 16      8  (0, 2, 2)  3292.398772   979.834158  3308.257348  3292.415256
# 17     16  (1, 2, 1)  3292.421833   979.872637  3308.280408  3292.438317
# 18     25  (2, 2, 1)  3292.901082    978.55261  3314.045849  3292.928574
# 19     17  (1, 2, 2)   3293.92467   980.498296  3315.069436  3293.952161
# 20     26  (2, 2, 2)  3296.422905   979.928181  3322.853864  3296.464171
# 21     24  (2, 2, 0)   3753.14711  1280.619941  3769.005685  3753.163593
# 22     15  (1, 2, 0)  3906.832228  1190.822203  3917.404612  3906.840464
# 23      6  (0, 2, 0)   4312.13541    910.60142  4317.421602  4312.138153
# 24      2  (0, 0, 2)  4456.982561   788.575131  4478.132804  4457.010015
# 25      1  (0, 0, 1)  5177.445225   788.589234  5193.307907  5177.461686
# 26      0  (0, 0, 0)  6583.097049   788.577678   6593.67217  6583.105274
#
#           RMSE                 MAPE  \
# 0    98.325312   7896052927511372.0
# 1    98.113261   7845928094821120.0
# 2    98.107902   7844659452207841.0
# 3    98.093781   7841301217884196.0
# 4    95.405232   7187029713371058.0
# 5    95.402216   7186538538076332.0
# 6    95.403742   7186914531235306.0
# 7    95.405499   7187113662751370.0
# 8    95.405698   7187317419217183.0
# 9    95.403174   7186679740617433.0
# 10    98.77145   7998380280242316.0
# 11   98.769377   7997902766544984.0
# 12   98.771414   7998371986649150.0
# 13   98.771427   7998375022000958.0
# 14   98.770137   7998077616825984.0
# 15  102.316817   9193997384402578.0
# 16  102.306097   9190528054604356.0
# 17  102.307479   9190974154138802.0
# 18  102.259968   9175721130437900.0
# 19  102.330359   9197340515550980.0
# 20  102.309489   9191612164192464.0
# 21  114.104552  12641579735738394.0
# 22  110.388133  11617714104528378.0
# 23   99.881568   8384423112412822.0
# 24   95.365433   7186503475025327.0
# 25   95.368962   7186632012352950.0
# 26   95.371364   7186526671920881.0
#
#                                                 model
# 0   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 1   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 2   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 3   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 4   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 5   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 6   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 7   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 8   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 9   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 10  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 11  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 12  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 13  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 14  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 15  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 16  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 17  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 18  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 19  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 20  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 21  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 22  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 23  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 24  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 25  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 26  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...

# %%
for df in dfs:
    plot_forecast(best_m, '2016', df_train[df], df_test[df])

# %% [markdown]
# ## Forecasting with Seasonal ARIMA

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
sarima_model = SARIMAX(df_train['price'], 
                       order=(0,1,1),
                       seasonal_order=(0,1,1,12))
model = sarima_model.fit(disp=0)

# %%
model.plot_diagnostics(figsize=(15,7)); plt.show()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              price   No. Observations:                 1462
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood               -8432.504
# Date:                            Thu, 06 Oct 2022   AIC                          16871.009
# Time:                                    08:29:36   BIC                          16886.844
# Sample:                                01-01-2016   HQIC                         16876.918
#                                      - 01-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0014      0.018     -0.077      0.939      -0.037       0.034
# ma.S.L12      -0.9989      0.101     -9.880      0.000      -1.197      -0.801
# sigma2      6396.2754    635.758     10.061      0.000    5150.213    7642.338
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             10287.89
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.41   Skew:                            -1.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
plot_forecast(model, '2016', df_train['price'], df_test['price'])

# %%
P_ns, D_ns, Q_ns = [list(range(3))]*3
P_s, D_s, Q_s = [list(range(2))]*3
vals = combinator([P_ns, D_ns, Q_ns, P_s, D_s, Q_s])
score = {}
for i, (p, d, q, P, D, Q) in enumerate(vals):
    if i%15 == 0:
        print(f'Running model #{i} using SARIMA({p},{d},{q}) ({P},{D},{Q},12)')
    m = SARIMAX(df_train['price'], 
                order=(p,d,q),
                seasonal_order=(P, D, Q, 12),
                enforce_stationarity=False)
    res = m.fit(disp=0)
    y = df_test['price'].values.ravel() 
    y_hat = res.forecast(steps=len(y))
    score[i] = {'non-seasonal order': (p,d,q),
                'seasonal order': (P, D, Q),
                'AIC':res.aic, 
                'AICc': res.aicc,
                'BIC': res.bic,
                'RMSPE': rmspe(y, y_hat),
                'RMSE' : rmse(y, y_hat),
                'MAPE' : mape(y, y_hat),
                'model': res}
# Out:
# Running model #0 using SARIMA(0,0,0) (0,0,0,12)
# Running model #15 using SARIMA(0,0,1) (1,1,1,12)
# Running model #30 using SARIMA(0,1,0) (1,1,0,12)
# Running model #45 using SARIMA(0,1,2) (1,0,1,12)
# Running model #60 using SARIMA(0,2,1) (1,0,0,12)
# Running model #75 using SARIMA(1,0,0) (0,1,1,12)
# Running model #90 using SARIMA(1,0,2) (0,1,0,12)
# Running model #105 using SARIMA(1,1,1) (0,0,1,12)
# Running model #120 using SARIMA(1,2,0) (0,0,0,12)
# Running model #135 using SARIMA(1,2,1) (1,1,1,12)
# Running model #150 using SARIMA(2,0,0) (1,1,0,12)
# Running model #165 using SARIMA(2,0,2) (1,0,1,12)
# Running model #180 using SARIMA(2,1,1) (1,0,0,12)
# Running model #195 using SARIMA(2,2,0) (0,1,1,12)
# Running model #210 using SARIMA(2,2,2) (0,1,0,12)

# %%
best_model = get_best_model(score, 'AIC')
# Out:
# Best model: 187 with lowest AIC score: 16528.144359680377

# %%
score[187]
# Out:
# {'non-seasonal order': (2, 1, 2),
#  'seasonal order': (0, 1, 1),
#  'AIC': 16528.144359680377,
#  'AICc': 16528.203224431603,
#  'BIC': 16559.753697807333,
#  'RMSPE': 1.6294024586068936,
#  'RMSE': 715.1755394791252,
#  'MAPE': 0.15354702619448746,
#  'model': <statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x1d2cd3caeb0>}

# %%
plot_forecast(best_model, '2016', df_train['price'], df_test['price'])

# %%
pd.DataFrame(score).T.sort_values(by='AIC').reset_index()
# Out:
#      index non-seasonal order seasonal order           AIC          AICc  \
# 0      187          (2, 1, 2)      (0, 1, 1)   16528.14436  16528.203224
# 1      191          (2, 1, 2)      (1, 1, 1)  16554.813595  16554.892136
# 2      185          (2, 1, 2)      (0, 0, 1)  16605.466337  16605.524711
# 3      189          (2, 1, 2)      (1, 0, 1)  16607.226244   16607.30413
# 4      115          (1, 1, 2)      (0, 1, 1)  16613.832557  16613.874574
# ..     ...                ...            ...           ...           ...
# 211      9          (0, 0, 1)      (0, 0, 1)  23533.522116  23533.538736
# 212     16          (0, 0, 2)      (0, 0, 0)  23675.024611  23675.041106
# 213      1          (0, 0, 0)      (0, 0, 1)  25242.239919  25242.248217
# 214      8          (0, 0, 1)      (0, 0, 0)   25385.14357  25385.151806
# 215      0          (0, 0, 0)      (0, 0, 0)  27366.212332  27366.215074
#
#               BIC     RMSPE         RMSE      MAPE  \
# 0    16559.753698  1.629402   715.175539  0.153547
# 1    16591.691156  1.633934   717.102309  0.154091
# 2    16637.125676  2.111731   920.756246  0.204034
# 3    16644.162139  2.100013    915.76582  0.202802
# 4    16640.173672  2.273843   989.007522  0.221737
# ..            ...       ...          ...       ...
# 211  23549.355932  9.943642  4228.413365  0.992668
# 212  23690.881131  9.990644   4247.92507  0.998675
# 213  25252.797177  9.948291  4229.783875  0.993449
# 214  25395.715953  9.994529   4249.15424  0.999251
# 215  27371.499208      10.0   4250.86806       1.0
#
#                                                  model
# 0    <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 1    <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 2    <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 3    <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 4    <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# ..                                                 ...
# 211  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 212  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 213  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 214  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 215  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
#
# [216 rows x 10 columns]

# %% [markdown]
# ## Forecasting using Facebook Prophet

# %%
#!pip install pystan

# %%
#!pip install prophet

# %%
#!pip install plotly

# %%
from prophet import Prophet

# %%
gold = pd.read_csv('Gold_data.csv', parse_dates=['date']) 
gold.columns = ['ds', 'y']

# %%
gold.head()
# Out:
#           ds        y
# 0 2016-01-01  2252.60
# 1 2016-01-02  2454.50
# 2 2016-01-03  2708.10
# 3 2016-01-04  2577.80
# 4 2016-01-05  2597.75

# %%
idx = round(len(gold) * 0.70)
train = gold[:idx]
test = gold[idx:]

# %%
print(f'Train: {train.shape}')
print(f'Test: {test.shape}')
# Out:
# Train: (1527, 2)
# Test: (655, 2)

# %%
from prophet import Prophet
model = Prophet().fit(train)
# Out:
# 08:54:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:54:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(len(test)+30)

# %%
len(gold) == len(future)
# Out:
# False

# %%
forecast = model.predict(future)
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'weekly', 'weekly_lower', 'weekly_upper', 'yearly', 'yearly_lower',
#        'yearly_upper', 'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
cols = ['ds', 'yhat', 'yhat_lower', 'yhat_upper']

# %%
model.plot(forecast, ylabel='Gold Price')
plt.show()

# %%
predicted = model.predict(test)
model.plot(predicted, ylabel='Gold Price')
plt.show()

# %%
model.plot_components(forecast); 
plt.show()

# %%
ax = test.plot(x='ds', y='y', 
                    label='Actual', 
                    style='-.', 
                    figsize=(12,4))
predicted.plot(x='ds', y='yhat', 
               label='Predicted', 
               ax=ax)
plt.title('Gold Price Actual vs Forecast')
plt.show()

# %%
model.changepoints.head()
# Out:
# 49    2016-02-19
# 98    2016-04-08
# 146   2016-05-26
# 195   2016-07-14
# 244   2016-09-01
# Name: ds, dtype: datetime64[ns]

# %%
ax = gold.set_index('ds').plot(figsize=(12,5))
gold.set_index('ds').loc[model.changepoints].plot(style='o', ax=ax)
plt.legend(['original data', 'changepoints'])
plt.show()

# %%
from prophet.plot import add_changepoints_to_plot
fig = model.plot(forecast, ylabel='Gold Price')
add_changepoints_to_plot(fig.gca(), model, forecast)
plt.show()

# %% [markdown]
# # FINAL MODEL

# %%
gold=pd.read_csv('Gold_data.csv')
gold['date'] = pd.to_datetime(gold['date'])
gold.set_index('date',inplace=True)
gold
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# ...             ...
# 2021-12-17  4394.40
# 2021-12-18  4389.50
# 2021-12-19  4389.50
# 2021-12-20  4354.10
# 2021-12-21  4346.50
#
# [2182 rows x 1 columns]

# %%
hwf_final_model = ExponentialSmoothing(gold['price'],trend='add',seasonal='mul',seasonal_periods=366).fit()
final_prediction = np.round(hwf_final_model.forecast(30),2)
final_prediction_df = pd.DataFrame(final_prediction,columns=['price'])

# %%
final_prediction_df
# Out:
#               price
# 2021-12-22  4355.68
# 2021-12-23  4343.67
# 2021-12-24  4354.61
# 2021-12-25  4371.57
# 2021-12-26  4380.44
# 2021-12-27  4394.77
# 2021-12-28  4406.19
# 2021-12-29  4402.40
# 2021-12-30  4409.98
# 2021-12-31  4422.59
# 2022-01-01  4424.17
# 2022-01-02  4424.88
# 2022-01-03  4444.69
# 2022-01-04  4381.28
# 2022-01-05  4464.46
# 2022-01-06  4599.17
# 2022-01-07  4749.13
# 2022-01-08  4698.11
# 2022-01-09  4884.19
# 2022-01-10  4846.69
# 2022-01-11  4882.04
# 2022-01-12  4899.99
# 2022-01-13  4848.78
# 2022-01-14  4639.24
# 2022-01-15  4474.09
# 2022-01-16  4421.78
# 2022-01-17  4371.36
# 2022-01-18  4372.30
# 2022-01-19  4381.19
# 2022-01-20  4375.61

# %%
plt.figure(figsize=(15,8))
gold.price.plot()
final_prediction_df.price.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
final_prediction_df.price.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 30 days forecasted gold prices

# %% [markdown]
# # DEPLOYMENT using Streamlit

# %%
import pickle
from pickle import dump
from pickle import load
import streamlit

# %%
dump(hwf_final_model,open('model.sav','wb'))

# %%
loaded_model=load(open('model.sav','rb'))

# %%
#!streamlit run app.py
